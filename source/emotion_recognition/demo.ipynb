# %% [markdown]
# ##AudioVisualMerge
# ####Combine the predictions from audio2emotion and visual2emotion modules and generate one single output vector for music generation.

# %% [markdown]
# ###import libraries

# %%
from keras.models import load_model
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# modules for visual data parsing
import cv2
import imutils
import dlib
from imutils import face_utils

# modules for audio data parsing
import librosa
import subprocess
import librosa.display
import IPython.display as ipd
from IPython.core.display import display
import pandas as pd
from sklearn.preprocessing import StandardScaler
from joblib import load

# %% [markdown]
# ###Predict emotion using audio and visual models seperately.

# %% [markdown]
# ####Load video

# %% [markdown]
# #####**Demo video from Divit**

# %%
# !gdown --id 1NFqhQls1CQhN5jHlYiikB86AJT-mY9YY
demo_path = "/content/demo.mp4"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1NFqhQls1CQhN5jHlYiikB86AJT-mY9YY
# To: /content/demo.mp4
# 100% 23.5M/23.5M [00:00<00:00, 80.0MB/s]

# %% [markdown]
# #####Angry demo video

# %%
# !gdown --id 1a7Ggt0vYCvG4LyUT1FccxRUhd7xcdDwt
angry_demo_path = "/content/angry.mov"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1a7Ggt0vYCvG4LyUT1FccxRUhd7xcdDwt
# To: /content/angry.mov
# 100% 3.29M/3.29M [00:00<00:00, 27.5MB/s]

# %% [markdown]
# #####Calm demo video

# %%
# !gdown --id 1Cb8rA59g9RvUZFZ8ho5LBc0QmOP9aXob
calm_demo_path = "/content/calm_demo.mov"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Cb8rA59g9RvUZFZ8ho5LBc0QmOP9aXob
# To: /content/calm_demo.mov
# 100% 17.4M/17.4M [00:00<00:00, 36.9MB/s]

# %% [markdown]
# #####Disgust demo video

# %%
# !gdown --id 1TFy7uvQyPIprvrHTJqC9hl-kBzn7Nw7h
disgust_demo_path = "/content/disgust.mov"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1TFy7uvQyPIprvrHTJqC9hl-kBzn7Nw7h
# To: /content/disgust.mov
# 100% 24.3M/24.3M [00:00<00:00, 155MB/s]

# %% [markdown]
# #####Happy demo video

# %%
# !gdown --id 1fmEy4bPjUvXIM9ZMCMUEgpbXWciICddD
happy_demo_path = "content/happy.mov"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1fmEy4bPjUvXIM9ZMCMUEgpbXWciICddD
# To: /content/happy.mov
# 100% 2.65M/2.65M [00:00<00:00, 238MB/s]

# %%
# !gdown --id 1MU3nBa3nLHK1qiY7jCRG29P5BC6jGELx
happy_demo_path_2 = "content/happy.mov"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1MU3nBa3nLHK1qiY7jCRG29P5BC6jGELx
# To: /content/happy.mov
# 100% 5.11M/5.11M [00:00<00:00, 54.0MB/s]

# %% [markdown]
# ####**audio2emotion**

# %%
def get_audio_path(path):
  command = "ffmpeg -i " + path + " -ab 160k -ac 2 -ar 16000 -vn demo.wav"
  subprocess.call(command, shell=True)
  audio_path = "/content/demo.wav"
  return audio_path

# %%
a = get_audio_path(demo_path)

# %% [markdown]
# convert video (.mov) file to audio (.wav)

# %% [markdown]
# #####Audio Preprocessing
# As audio has different length and the FFT will produce distortions. We need to cut a long audio file into several short segments. In other word, we will divide the signal into frames. Each audio frame will have 50% overlap since we loose infomration on the edge of each frame after using a window function. The audio prediction is made in every 3 seconds.

# %%
def extract_features(data):
    result = np.array([])

    # 13 MFCCs
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=16000, n_mfcc = 13).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=16000).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # spectral centroid
    spec = np.mean(librosa.feature.spectral_centroid(y = data, sr = 16000, n_fft = 1024, hop_length = 512)[0])
    result = np.hstack((result, spec)) # stacking horizontally

    return result

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
'''def slice_frame(file, sample_rate = 16000):
  data_per_frame = []

  signal, sr = librosa.load(file, sr = sample_rate)
  duration = librosa.get_duration(y = signal, sr = sample_rate)

  #slice the audio into every 1 seconds
  num_frames = int(duration)
  #print("num_frames:", num_frames)
  window_hop = sample_rate // 2

  for n in range(num_frames * 2 - 1):
    #print("n:", n)
    start = window_hop * n
    finish = start + sample_rate
    sliced_data = signal[start:finish]
    #print("sliced_data:", sliced_data)

    data_per_frame.append(sliced_data)
    #print("length of data_per_frame:", len(data_per_frame))
    #print("data_per_frame:", data_per_frame)

  return data_per_frame

    #calc_features_per_frame = extract_features(sliced_data)
    #result = np.array(calc_features_per_frame)
    #result = np.append(result)
    #print(result)
    #print("/n")

    #result_per_frame.append(result)
    #print(result_per_frame)
    #print("/s")
'''
# Out:
# 'def slice_frame(file, sample_rate = 16000):\n  data_per_frame = []\n\n  signal, sr = librosa.load(file, sr = sample_rate)\n  duration = librosa.get_duration(y = signal, sr = sample_rate)\n\n  #slice the audio into every 1 seconds\n  num_frames = int(duration)\n  #print("num_frames:", num_frames)\n  window_hop = sample_rate // 2\n\n  for n in range(num_frames * 2 - 1):\n    #print("n:", n)\n    start = window_hop * n\n    finish = start + sample_rate\n    sliced_data = signal[start:finish]\n    #print("sliced_data:", sliced_data)\n    \n    data_per_frame.append(sliced_data)\n    #print("length of data_per_frame:", len(data_per_frame))\n    #print("data_per_frame:", data_per_frame)\n  \n  return data_per_frame\n\n    #calc_features_per_frame = extract_features(sliced_data)\n    #result = np.array(calc_features_per_frame)\n    #result = np.append(result)\n    #print(result)\n    #print("/n")\n    \n    #result_per_frame.append(result)\n    #print(result_per_frame)\n    #print("/s")\n'

# %%
def slice_frame(file, sample_rate = 16000):
  data_per_frame = []

  signal, sr = librosa.load(file, sr = sample_rate)
  duration = librosa.get_duration(y = signal, sr = sample_rate)

  samples_per_file = sample_rate * duration
  num_frames = int(duration / 3) #slice the audio into three seconds each
  sample_per_frame = int(samples_per_file / num_frames)
  window_hop = sample_per_frame // 2


  for n in range(num_frames * 2 - 1):
    start = window_hop * n
    finish = start + sample_per_frame
    sliced_data = signal[start:finish]

    data_per_frame.append(sliced_data)

  return data_per_frame

# %%
#load scaler from the audio2emotion source code
# !gdown --id 1fKfZSgw7bcm7v_4teVYeWgOoPr0z60-i
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1fKfZSgw7bcm7v_4teVYeWgOoPr0z60-i
# To: /content/scaler.pkl
# 100% 1.25k/1.25k [00:00<00:00, 1.94MB/s]

# %%
scaler = load(open('scaler.pkl', 'rb'))

# %%
def frame_features(file):
  frame_data = slice_frame(file)

  calc_features = []
  for list in frame_data:
    #original data
    frame_result = extract_features(list)
    result = np.array(frame_result)
    #print("origin result: ", result)

    #data with noise
    noise_data = noise(list)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2))
    #print("noise result: ", res2)

    #data with stretching and pitching
    new_data = stretch(list)
    data_stretch_pitch = pitch(new_data, 16000)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3))
    #print("stretchpitch result: ", res3)

    #add scaler
    combine_array = np.array(result)
    combine_array_scaled = scaler.transform(combine_array)

    calc_features.append(combine_array_scaled)

  return calc_features

# %%
feature_lists = frame_features(a)

# %% [markdown]
# #####Use pretrained model to predict emotions
# Note: {0: 'angry',
#  1: 'calm',
#  2: 'disgust',
#  3: 'fear',
#  4: 'happy',
#  5: 'neutral',
#  6: 'sad',
#  7: 'surprise'}

# %%
# !gdown --id 1tZwJn00OjoT3painOq9t9BvsbDGD5a0n
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1tZwJn00OjoT3painOq9t9BvsbDGD5a0n
# To: /content/audio_model.h5
# 100% 6.53M/6.53M [00:00<00:00, 82.8MB/s]

# %%
audio_model = load_model('/content/audio_model.h5')
audio_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 27, 256)           1536
#
#  max_pooling1d (MaxPooling1D  (None, 14, 256)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 14, 256)           327936
#
#  max_pooling1d_1 (MaxPooling  (None, 7, 256)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 7, 128)            163968
#
#  max_pooling1d_2 (MaxPooling  (None, 4, 128)           0
#  1D)
#
#  dropout (Dropout)           (None, 4, 128)            0
#
#  conv1d_3 (Conv1D)           (None, 4, 64)             41024
#
#  max_pooling1d_3 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 538,856
# Trainable params: 538,856
# Non-trainable params: 0
# _________________________________________________________________

# %%
def audio_predict(path):
  feature_input = frame_features(path)
  audio_prediction_vectors = []
  audio_prediction_labels = []


  for list in feature_input:
    features = list
    #reshape the features to fit the model
    expand_features = np.expand_dims(features, axis = 2)

    #feed the features into the model for prediction
    frame_predict = audio_model.predict(expand_features)
    #print("frame_predict:", frame_predict)

    #prediction vector on every frame
    frame_predict_output = frame_predict[0]
    #print("frame_predict_output:", frame_predict_output)

    #prediction label on every frame
    frame_predict_maxindex = np.argmax(frame_predict_output)
    frame_predict_label = predictions_dict[frame_predict_maxindex]
    #print("frame_predict_label:", frame_predict_label)

    audio_prediction_vectors.append(frame_predict_output)
    audio_prediction_labels.append(frame_predict_label)

  # Duplicate the first and last prediction so length match
  first_prediction_vector = audio_prediction_vectors[0]
  first_prediction_label = audio_prediction_labels[0]
  last_prediction_vector = audio_prediction_vectors[-1]
  last_prediction_label = audio_prediction_labels[-1]

  audio_prediction_vectors.insert(0, first_prediction_vector)
  audio_prediction_vectors.append(last_prediction_vector)

  audio_prediction_labels.insert(0, first_prediction_label)
  audio_prediction_labels.append(last_prediction_label)

  return audio_prediction_vectors, audio_prediction_labels

# %%
audio_predict(a)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# ([array([1.3140957e-09, 5.7198145e-06, 2.0345067e-10, 1.3066876e-09,
#          1.4270027e-10, 1.4440648e-08, 9.9999428e-01, 3.2274528e-16],
#         dtype=float32),
#   array([1.3140957e-09, 5.7198145e-06, 2.0345067e-10, 1.3066876e-09,
#          1.4270027e-10, 1.4440648e-08, 9.9999428e-01, 3.2274528e-16],
#         dtype=float32),
#   array([2.4631059e-09, 9.9684203e-01, 1.9211394e-07, 4.0048440e-10,
#          1.8781188e-09, 2.9459214e-04, 2.8631915e-03, 1.6728092e-12],
#         dtype=float32),
#   array([1.5063922e-11, 9.9946028e-01, 1.7257202e-08, 3.3309117e-13,
#          2.6988366e-11, 2.6456502e-05, 5.1321933e-04, 6.3468518e-16],
#         dtype=float32),
#   array([1.8731585e-07, 3.6519300e-06, 9.9994409e-01, 4.1358261e-14,
#          3.6641993e-08, 1.0048250e-06, 5.0961506e-05, 7.7407915e-12],
#         dtype=float32),
#   array([3.6091135e-09, 9.9152970e-01, 1.5805977e-03, 1.4986117e-12,
#          1.3454746e-09, 4.2967231e-04, 6.4600967e-03, 2.5820386e-13],
#         dtype=float32),
#   array([2.1928912e-05, 1.0164180e-03, 9.8868936e-01, 2.9817540e-09,
#          3.2370157e-05, 2.6514812e-03, 7.5883088e-03, 7.7019202e-08],
#         dtype=float32),
#   array([3.3932045e-11, 9.9817204e-01, 2.5852918e-07, 1.2453310e-12,
#          2.2584911e-11, 2.5153029e-04, 1.5761866e-03, 3.6723520e-15],
#         dtype=float32),
#   array([1.4626043e-14, 9.9969459e-01, 4.0725142e-11, 1.1166112e-14,
#          3.0302182e-15, 3.3429842e-06, 3.0213647e-04, 4.5980334e-19],
#         dtype=float32),
#   array([2.2792704e-01, 1.3544323e-04, 1.7691825e-02, 4.7114550e-08,
#          1.3496891e-05, 1.5119023e-06, 7.5423056e-01, 1.1089366e-10],
#         dtype=float32),
#   array([1.4102750e-03, 1.5652630e-11, 9.9833101e-01, 4.9273675e-12,
#          2.2993812e-04, 2.7039559e-10, 2.8774641e-05, 2.5894173e-09],
#         dtype=float32),
#   array([1.17432304e-04, 3.52286843e-05, 9.98484552e-01, 2.53031845e-10,
#          1.21914672e-04, 5.74231744e-05, 1.18341763e-03, 1.40242236e-08],
#         dtype=float32),
#   array([1.2227068e-06, 9.1418499e-01, 1.4089829e-03, 8.6192031e-08,
#          1.4668144e-06, 8.1859371e-03, 7.6217219e-02, 8.8872870e-10],
#         dtype=float32),
#   array([1.5600137e-01, 1.0877025e-10, 8.4377629e-01, 5.0606214e-11,
#          1.8309134e-04, 3.9800699e-10, 3.9222814e-05, 9.0578185e-09],
#         dtype=float32),
#   array([7.6702857e-01, 4.5246864e-09, 2.2072153e-01, 8.1944268e-10,
#          3.3045642e-06, 9.5671437e-10, 1.2246559e-02, 1.9089752e-09],
#         dtype=float32),
#   array([2.2534993e-14, 5.1753605e-03, 1.9067372e-13, 1.2507992e-11,
#          8.4651619e-14, 1.6089342e-07, 9.9482453e-01, 7.3712094e-20],
#         dtype=float32),
#   array([3.7961512e-11, 9.7874600e-01, 2.5033879e-09, 2.7885552e-11,
#          8.1602320e-12, 2.5118303e-05, 2.1228878e-02, 1.9536762e-16],
#         dtype=float32),
#   array([2.1575164e-05, 5.2505569e-11, 9.9997830e-01, 1.4059574e-15,
#          1.1935726e-09, 2.3402578e-11, 7.4947238e-08, 2.3985765e-11],
#         dtype=float32),
#   array([4.6252158e-06, 5.8153051e-01, 5.2064687e-02, 1.2493895e-09,
#          5.8150330e-05, 1.5096582e-01, 2.1537623e-01, 8.9643926e-10],
#         dtype=float32),
#   array([7.8643706e-07, 7.3791085e-08, 9.9999583e-01, 4.8805182e-13,
#          4.7283791e-08, 5.0471964e-08, 3.2092737e-06, 2.3939986e-10],
#         dtype=float32),
#   array([1.8644949e-08, 1.1180762e-05, 9.9997592e-01, 3.9192274e-12,
#          4.2952757e-09, 7.1151277e-07, 1.2181734e-05, 6.0707772e-11],
#         dtype=float32),
#   array([5.9838698e-08, 1.5338262e-09, 9.9999750e-01, 4.1001737e-11,
#          6.5567730e-07, 1.7273594e-08, 1.7911113e-06, 1.4704967e-08],
#         dtype=float32),
#   array([4.35650145e-06, 1.28606120e-02, 2.64120917e-03, 1.28541315e-05,
#          6.00652129e-06, 1.06683210e-03, 9.83408153e-01, 7.22011517e-09],
#         dtype=float32),
#   array([5.8469479e-10, 9.6210194e-01, 6.5447571e-04, 4.1940011e-15,
#          5.9625416e-10, 3.4896267e-04, 3.6894575e-02, 1.3433865e-14],
#         dtype=float32),
#   array([2.8031835e-16, 9.9998701e-01, 1.3777744e-11, 3.4987819e-19,
#          3.1668169e-16, 2.3285638e-07, 1.2742660e-05, 2.2061794e-22],
#         dtype=float32),
#   array([1.4736014e-12, 9.9995339e-01, 4.3310898e-08, 5.6966280e-16,
#          1.0770883e-12, 5.4107968e-06, 4.1198069e-05, 2.2210813e-18],
#         dtype=float32),
#   array([1.2609196e-06, 1.9575247e-04, 9.9972004e-01, 1.1338424e-12,
#          1.4803309e-06, 5.4202496e-06, 7.6090808e-05, 8.0396528e-10],
#         dtype=float32),
#   array([7.3991564e-15, 9.9997365e-01, 4.7260855e-11, 1.7953246e-16,
#          4.5607837e-15, 2.1686186e-07, 2.6056432e-05, 4.9611262e-20],
#         dtype=float32),
#   array([1.5975880e-13, 9.9990809e-01, 2.3044126e-10, 1.2773375e-14,
#          1.2745394e-13, 8.4810517e-07, 9.1022172e-05, 6.5089271e-18],
#         dtype=float32),
#   array([1.2258606e-08, 9.9690491e-01, 1.0900894e-05, 4.1174782e-11,
#          1.1670679e-08, 1.2303336e-03, 1.8537459e-03, 1.1722971e-12],
#         dtype=float32),
#   array([4.0216331e-04, 1.4249257e-12, 1.2770166e-03, 1.8119376e-07,
#          9.9634820e-01, 1.3983884e-09, 1.9723848e-03, 1.1909018e-08],
#         dtype=float32),
#   array([1.0419374e-04, 4.5344286e-06, 4.2854458e-01, 1.8105482e-07,
#          4.8646003e-01, 4.4816782e-04, 8.4438279e-02, 1.8442800e-07],
#         dtype=float32),
#   array([1.0419374e-04, 4.5344286e-06, 4.2854458e-01, 1.8105482e-07,
#          4.8646003e-01, 4.4816782e-04, 8.4438279e-02, 1.8442800e-07],
#         dtype=float32)],
#  ['sad',
#   'sad',
#   'calm',
#   'calm',
#   'disgust',
#   'calm',
#   'disgust',
#   'calm',
#   'calm',
#   'sad',
#   'disgust',
#   'disgust',
#   'calm',
#   'disgust',
#   'angry',
#   'sad',
#   'calm',
#   'disgust',
#   'calm',
#   'disgust',
#   'disgust',
#   'disgust',
#   'sad',
#   'calm',
#   'calm',
#   'calm',
#   'disgust',
#   'calm',
#   'calm',
#   'calm',
#   'happy',
#   'happy',
#   'happy'])

# %% [markdown]
# ####**visual2emotion**
# *Note*: The visual2emotion model detects emotions based on key frame. Essentially, we can make a decision whenever we want.
#
# To coordinate better with audio data, we choose to make a decision every xxxx second.

# %% [markdown]
# #####Visual Preprocessing
# Our visual model takes landmarks features as input, so we need to parse the video, extract the key frames and corresponding landmarks, and then feed into the pre-trained model.

# %%
# download dlib pretrained library
# !gdown --id 1XqF2ec7KdVrrxrnahWeKCJrHOR_ucX2o
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1XqF2ec7KdVrrxrnahWeKCJrHOR_ucX2o
# To: /content/shape_predictor_68_face_landmarks.dat
# 100% 99.7M/99.7M [00:01<00:00, 52.0MB/s]

# %%
# Helper functions for video parsing

#dlib model setup
# initialize dlib's face detector (HOG-based) and create facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("/content/shape_predictor_68_face_landmarks.dat")

# dlib helper functions
# take a bounding predicted by dlib and convert it to the format (x, y, w, h) as
# we would normally do with OpenCV
def rect_to_bb(rect):
	x = rect.left()
	y = rect.top()
	w = rect.right() - x
	h = rect.bottom() - y
	# return a tuple of (x, y, w, h)
	return (x, y, w, h)

# initialize the list of (x, y)-coordinates
def shape_to_np(shape, dtype="int"):
	coords = np.zeros((68, 2), dtype=dtype)
	# loop over the 68 facial landmarks and convert them
	# to a 2-tuple of (x, y)-coordinates
	for i in range(0, 68):
		coords[i] = (shape.part(i).x, shape.part(i).y)
	# return the list of (x, y)-coordinates
	return coords

# %%
# Helper function for data parsing
# Use dlib to get landmark
# Store the latest landmark every 3 seconds as the output array
# return [landmarks1, landmarks2, landmarks3...]
def get_landmark(path):
  print(f"Parsing file <path: {path}> ")
  cap = cv2.VideoCapture(path)
  total_count = 0
  capture_count = 0

  result = [] # a list of landmarks
  latest_capture = None # latest landmarks captured
  first_capture_flag = False # flag to mark whether we've got the first capture
  second_capture_flag = False # flag to mark whether we've got the second capture
  # Read the image and parse the facial landmarks every 1000ms
  while True:
    total_count += 1
    capture_count += 1
    # use cap to read key frame
    ret, image = cap.read()
    print(f"Trying to capture frame {total_count}...")

    if ret is not True:
      print(f"Total frame count: {total_count}")
      print(f"{len(result)} frame of landmarks captured")
      break

    else:
      # Append latest capture to result every 1.5 seconds
      if capture_count >= 45:
        if first_capture_flag and second_capture_flag:
          result.append(latest_capture)
        capture_count = 0 # reset capture_count

      # resize the input image, and convert it to grayscale
      image = imutils.resize(image, width=500)
      gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

      # detect faces in the grayscale image
      rects = detector(gray, 1)
      try:
        rect = rects[0] # only one face
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)

        # convert dlib's rectangle to a OpenCV-style bounding box
        # [i.e., (x, y, w, h)], then draw the face bounding box
        (x, y, w, h) = face_utils.rect_to_bb(rect)
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        print("Captured!")
        latest_capture = shape[17:] # updated latest capture

        # If no frame is capture in the first 3 seconds
        if total_count > 45 and not first_capture_flag:
          result.append(latest_capture)
          first_capture_flag = True

        if total_count > 90 and not second_capture_flag:
          result.append(latest_capture)
          second_capture_flag = True

      except IndexError:
        continue


  # Release all space and windows once done
  cap.release()
  cv2.destroyAllWindows()

  print(f"Total frame count: {total_count}")
  print(f"{len(result)} frame of landmarks captured")
  return result

# %%
# Helper functions for feature extraction
# Calculate distance between two landmarks
def calc_distance(landmark1,landmark2):
  (x1, y1) = landmark1
  (x2, y2) = landmark2
  return ((x1-x2)**2+ (y1-y2)**2)**(0.5)

# Featurize and turn the facial landmarks into a 1-d array
def featurize(landmarks):
  res = []
  total_count = len(landmarks)
  for i in range(total_count - 1):
    for j in range(i + 1, total_count):
      res.append(calc_distance(landmarks[i], landmarks[j]))
  return np.array(res)

# %%
def parse_visual(path):
  landmarks_list = get_landmark(path)

  input = []
  for landmarks in landmarks_list:
    input.append(featurize(landmarks))
  return input

# %% [markdown]
# #####Use pretrained model to predict emotions
# #####Use pretrained model to predict emotions
# Note: Output 0-7 is corresponded to `['angry' 'calm' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']`.

# %%
predictions_dict = ['angry', 'calm', 'disgust', 'fear', 'happy', 'neutral', 'sad','surprise']

# %%
# load pretrained model from google drive
# !gdown --id 1-GFtUsUYzXHXTWluajl7PpEwDj6yfuxx
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-GFtUsUYzXHXTWluajl7PpEwDj6yfuxx
# To: /content/visual_model_full.h5
# 100% 12.8M/12.8M [00:00<00:00, 83.8MB/s]

# %%
visual_model = load_model("/content/visual_model_full.h5")
visual_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_4 (Batc  (None, 1275)             5100
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 1275)              0
#
#  dense_4 (Dense)             (None, 512)               653312
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 1,059,572
# Trainable params: 1,054,462
# Non-trainable params: 5,110
# _________________________________________________________________

# %%
def visual_predict(path):
  features = parse_visual(path)

  # Get the prediction vector for each features array
  visual_prediction_vectors = []
  visual_predictions = []
  for frame_feature in features:
    frame_feature_cnn = np.expand_dims(frame_feature, axis = 0)

    # use pre-trained model to predict emotion and store prediction matrix
    predictions = visual_model.predict(frame_feature_cnn)
    visual_prediction_vectors.append(predictions)

  # And an array of prediction emotions
  labels = []
  for vector in visual_prediction_vectors:
    max_index = np.argmax(vector)
    labels.append(predictions_dict[max_index])

  return visual_prediction_vectors, labels

# %%
visual_predict(demo_path)
# Out:
# Parsing file <path: /content/demo.mp4>
# Trying to capture frame 1...
# Trying to capture frame 2...
# Trying to capture frame 3...
# Trying to capture frame 4...
# Trying to capture frame 5...
# Trying to capture frame 6...
# Trying to capture frame 7...
# Trying to capture frame 8...
# Trying to capture frame 9...
# Trying to capture frame 10...
# Trying to capture frame 11...
# Trying to capture frame 12...
# Trying to capture frame 13...
# Trying to capture frame 14...
# Trying to capture frame 15...
# Trying to capture frame 16...
# Trying to capture frame 17...
# Trying to capture frame 18...
# Trying to capture frame 19...
# Trying to capture frame 20...
# Trying to capture frame 21...
# Trying to capture frame 22...
# Trying to capture frame 23...
# Trying to capture frame 24...
# Trying to capture frame 25...
# Trying to capture frame 26...
# Trying to capture frame 27...
# Trying to capture frame 28...
# Trying to capture frame 29...
# Trying to capture frame 30...
# Trying to capture frame 31...
# Trying to capture frame 32...
# Trying to capture frame 33...
# Trying to capture frame 34...
# Trying to capture frame 35...
# Trying to capture frame 36...
# Trying to capture frame 37...
# Trying to capture frame 38...
# Trying to capture frame 39...
# Trying to capture frame 40...
# Trying to capture frame 41...
# Trying to capture frame 42...
# Trying to capture frame 43...
# Trying to capture frame 44...
# Trying to capture frame 45...
# Trying to capture frame 46...
# Trying to capture frame 47...
# Trying to capture frame 48...
# Trying to capture frame 49...
# Trying to capture frame 50...
# Trying to capture frame 51...
# Trying to capture frame 52...
# Trying to capture frame 53...
# Trying to capture frame 54...
# Trying to capture frame 55...
# Trying to capture frame 56...
# Trying to capture frame 57...
# Trying to capture frame 58...
# Trying to capture frame 59...
# Trying to capture frame 60...
# Trying to capture frame 61...
# Trying to capture frame 62...
# Trying to capture frame 63...
# Trying to capture frame 64...
# Trying to capture frame 65...
# Trying to capture frame 66...
# Trying to capture frame 67...
# Trying to capture frame 68...
# Trying to capture frame 69...
# Trying to capture frame 70...
# Trying to capture frame 71...
# Trying to capture frame 72...
# Trying to capture frame 73...
# Trying to capture frame 74...
# Trying to capture frame 75...
# Trying to capture frame 76...
# Trying to capture frame 77...
# Trying to capture frame 78...
# Trying to capture frame 79...
# Trying to capture frame 80...
# Trying to capture frame 81...
# Trying to capture frame 82...
# Trying to capture frame 83...
# Trying to capture frame 84...
# Trying to capture frame 85...
# Trying to capture frame 86...
# Trying to capture frame 87...
# Trying to capture frame 88...
# Trying to capture frame 89...
# Trying to capture frame 90...
# Trying to capture frame 91...
# Captured!
# Trying to capture frame 92...
# Captured!
# Trying to capture frame 93...
# Captured!
# Trying to capture frame 94...
# Captured!
# Trying to capture frame 95...
# Captured!
# Trying to capture frame 96...
# Trying to capture frame 97...
# Trying to capture frame 98...
# Trying to capture frame 99...
# Trying to capture frame 100...
# Trying to capture frame 101...
# Trying to capture frame 102...
# Trying to capture frame 103...
# Trying to capture frame 104...
# Trying to capture frame 105...
# Trying to capture frame 106...
# Trying to capture frame 107...
# Trying to capture frame 108...
# Trying to capture frame 109...
# Trying to capture frame 110...
# Trying to capture frame 111...
# Trying to capture frame 112...
# Trying to capture frame 113...
# Trying to capture frame 114...
# Trying to capture frame 115...
# Trying to capture frame 116...
# Trying to capture frame 117...
# Trying to capture frame 118...
# Trying to capture frame 119...
# Trying to capture frame 120...
# Trying to capture frame 121...
# Trying to capture frame 122...
# Trying to capture frame 123...
# Trying to capture frame 124...
# Captured!
# Trying to capture frame 125...
# Captured!
# Trying to capture frame 126...
# Captured!
# Trying to capture frame 127...
# Captured!
# Trying to capture frame 128...
# Captured!
# Trying to capture frame 129...
# Trying to capture frame 130...
# Trying to capture frame 131...
# Trying to capture frame 132...
# Trying to capture frame 133...
# Trying to capture frame 134...
# Trying to capture frame 135...
# Trying to capture frame 136...
# Trying to capture frame 137...
# Trying to capture frame 138...
# Trying to capture frame 139...
# Trying to capture frame 140...
# Trying to capture frame 141...
# Trying to capture frame 142...
# Trying to capture frame 143...
# Captured!
# Trying to capture frame 144...
# Trying to capture frame 145...
# Trying to capture frame 146...
# Trying to capture frame 147...
# Trying to capture frame 148...
# Trying to capture frame 149...
# Trying to capture frame 150...
# Trying to capture frame 151...
# Trying to capture frame 152...
# Trying to capture frame 153...
# Trying to capture frame 154...
# Trying to capture frame 155...
# Trying to capture frame 156...
# Trying to capture frame 157...
# Trying to capture frame 158...
# Trying to capture frame 159...
# Trying to capture frame 160...
# Trying to capture frame 161...
# Trying to capture frame 162...
# Trying to capture frame 163...
# Trying to capture frame 164...
# Trying to capture frame 165...
# Trying to capture frame 166...
# Trying to capture frame 167...
# Trying to capture frame 168...
# Trying to capture frame 169...
# Trying to capture frame 170...
# Trying to capture frame 171...
# Trying to capture frame 172...
# Trying to capture frame 173...
# Trying to capture frame 174...
# Trying to capture frame 175...
# Trying to capture frame 176...
# Trying to capture frame 177...
# Trying to capture frame 178...
# Trying to capture frame 179...
# Trying to capture frame 180...
# Trying to capture frame 181...
# Captured!
# Trying to capture frame 182...
# Captured!
# Trying to capture frame 183...
# Captured!
# Trying to capture frame 184...
# Captured!
# Trying to capture frame 185...
# Trying to capture frame 186...
# Trying to capture frame 187...
# Trying to capture frame 188...
# Trying to capture frame 189...
# Captured!
# Trying to capture frame 190...
# Captured!
# Trying to capture frame 191...
# Captured!
# Trying to capture frame 192...
# Captured!
# Trying to capture frame 193...
# Captured!
# Trying to capture frame 194...
# Trying to capture frame 195...
# Trying to capture frame 196...
# Captured!
# Trying to capture frame 197...
# Trying to capture frame 198...
# Captured!
# Trying to capture frame 199...
# Captured!
# Trying to capture frame 200...
# Trying to capture frame 201...
# Trying to capture frame 202...
# Trying to capture frame 203...
# Trying to capture frame 204...
# Trying to capture frame 205...
# Trying to capture frame 206...
# Trying to capture frame 207...
# Trying to capture frame 208...
# Trying to capture frame 209...
# Trying to capture frame 210...
# Trying to capture frame 211...
# Trying to capture frame 212...
# Trying to capture frame 213...
# Trying to capture frame 214...
# Trying to capture frame 215...
# Trying to capture frame 216...
# Trying to capture frame 217...
# Trying to capture frame 218...
# Trying to capture frame 219...
# Trying to capture frame 220...
# Trying to capture frame 221...
# Trying to capture frame 222...
# Trying to capture frame 223...
# Trying to capture frame 224...
# Trying to capture frame 225...
# Trying to capture frame 226...
# Trying to capture frame 227...
# Trying to capture frame 228...
# Trying to capture frame 229...
# Trying to capture frame 230...
# Trying to capture frame 231...
# Trying to capture frame 232...
# Trying to capture frame 233...
# Trying to capture frame 234...
# Trying to capture frame 235...
# Trying to capture frame 236...
# Trying to capture frame 237...
# Trying to capture frame 238...
# Trying to capture frame 239...
# Trying to capture frame 240...
# Trying to capture frame 241...
# Trying to capture frame 242...
# Trying to capture frame 243...
# Trying to capture frame 244...
# Trying to capture frame 245...
# Trying to capture frame 246...
# Trying to capture frame 247...
# Trying to capture frame 248...
# Trying to capture frame 249...
# Trying to capture frame 250...
# Trying to capture frame 251...
# Trying to capture frame 252...
# Trying to capture frame 253...
# Trying to capture frame 254...
# Trying to capture frame 255...
# Trying to capture frame 256...
# Trying to capture frame 257...
# Trying to capture frame 258...
# Trying to capture frame 259...
# Trying to capture frame 260...
# Trying to capture frame 261...
# Trying to capture frame 262...
# Trying to capture frame 263...
# Trying to capture frame 264...
# Trying to capture frame 265...
# Trying to capture frame 266...
# Trying to capture frame 267...
# Trying to capture frame 268...
# Trying to capture frame 269...
# Captured!
# Trying to capture frame 270...
# Trying to capture frame 271...
# Trying to capture frame 272...
# Trying to capture frame 273...
# Trying to capture frame 274...
# Trying to capture frame 275...
# Trying to capture frame 276...
# Trying to capture frame 277...
# Trying to capture frame 278...
# Trying to capture frame 279...
# Trying to capture frame 280...
# Trying to capture frame 281...
# Trying to capture frame 282...
# Trying to capture frame 283...
# Trying to capture frame 284...
# Trying to capture frame 285...
# Trying to capture frame 286...
# Trying to capture frame 287...
# Trying to capture frame 288...
# Trying to capture frame 289...
# Trying to capture frame 290...
# Trying to capture frame 291...
# Trying to capture frame 292...
# Trying to capture frame 293...
# Trying to capture frame 294...
# Trying to capture frame 295...
# Trying to capture frame 296...
# Trying to capture frame 297...
# Trying to capture frame 298...
# Trying to capture frame 299...
# Trying to capture frame 300...
# Trying to capture frame 301...
# Trying to capture frame 302...
# Trying to capture frame 303...
# Trying to capture frame 304...
# Trying to capture frame 305...
# Trying to capture frame 306...
# Trying to capture frame 307...
# Trying to capture frame 308...
# Trying to capture frame 309...
# Trying to capture frame 310...
# Trying to capture frame 311...
# Trying to capture frame 312...
# Trying to capture frame 313...
# Trying to capture frame 314...
# Trying to capture frame 315...
# Trying to capture frame 316...
# Trying to capture frame 317...
# Trying to capture frame 318...
# Trying to capture frame 319...
# Captured!
# Trying to capture frame 320...
# Trying to capture frame 321...
# Trying to capture frame 322...
# Trying to capture frame 323...
# Trying to capture frame 324...
# Trying to capture frame 325...
# Trying to capture frame 326...
# Trying to capture frame 327...
# Trying to capture frame 328...
# Trying to capture frame 329...
# Trying to capture frame 330...
# Trying to capture frame 331...
# Trying to capture frame 332...
# Trying to capture frame 333...
# Trying to capture frame 334...
# Trying to capture frame 335...
# Trying to capture frame 336...
# Trying to capture frame 337...
# Trying to capture frame 338...
# Trying to capture frame 339...
# Trying to capture frame 340...
# Trying to capture frame 341...
# Trying to capture frame 342...
# Trying to capture frame 343...
# Trying to capture frame 344...
# Trying to capture frame 345...
# Trying to capture frame 346...
# Trying to capture frame 347...
# Trying to capture frame 348...
# Trying to capture frame 349...
# Trying to capture frame 350...
# Trying to capture frame 351...
# Trying to capture frame 352...
# Trying to capture frame 353...
# Trying to capture frame 354...
# Trying to capture frame 355...
# Trying to capture frame 356...
# Trying to capture frame 357...
# Trying to capture frame 358...
# Trying to capture frame 359...
# Trying to capture frame 360...
# Trying to capture frame 361...
# Trying to capture frame 362...
# Trying to capture frame 363...
# Trying to capture frame 364...
# Trying to capture frame 365...
# Trying to capture frame 366...
# Trying to capture frame 367...
# Trying to capture frame 368...
# Trying to capture frame 369...
# Trying to capture frame 370...
# Trying to capture frame 371...
# Trying to capture frame 372...
# Trying to capture frame 373...
# Trying to capture frame 374...
# Trying to capture frame 375...
# Trying to capture frame 376...
# Trying to capture frame 377...
# Trying to capture frame 378...
# Trying to capture frame 379...
# Trying to capture frame 380...
# Trying to capture frame 381...
# Trying to capture frame 382...
# Trying to capture frame 383...
# Trying to capture frame 384...
# Trying to capture frame 385...
# Trying to capture frame 386...
# Trying to capture frame 387...
# Trying to capture frame 388...
# Trying to capture frame 389...
# Trying to capture frame 390...
# Trying to capture frame 391...
# Trying to capture frame 392...
# Trying to capture frame 393...
# Trying to capture frame 394...
# Trying to capture frame 395...
# Trying to capture frame 396...
# Trying to capture frame 397...
# Trying to capture frame 398...
# Trying to capture frame 399...
# Trying to capture frame 400...
# Trying to capture frame 401...
# Trying to capture frame 402...
# Trying to capture frame 403...
# Trying to capture frame 404...
# Trying to capture frame 405...
# Trying to capture frame 406...
# Trying to capture frame 407...
# Trying to capture frame 408...
# Trying to capture frame 409...
# Trying to capture frame 410...
# Trying to capture frame 411...
# Trying to capture frame 412...
# Trying to capture frame 413...
# Trying to capture frame 414...
# Trying to capture frame 415...
# Trying to capture frame 416...
# Trying to capture frame 417...
# Trying to capture frame 418...
# Trying to capture frame 419...
# Trying to capture frame 420...
# Trying to capture frame 421...
# Trying to capture frame 422...
# Trying to capture frame 423...
# Trying to capture frame 424...
# Trying to capture frame 425...
# Trying to capture frame 426...
# Trying to capture frame 427...
# Trying to capture frame 428...
# Trying to capture frame 429...
# Trying to capture frame 430...
# Trying to capture frame 431...
# Trying to capture frame 432...
# Trying to capture frame 433...
# Captured!
# Trying to capture frame 434...
# Trying to capture frame 435...
# Trying to capture frame 436...
# Trying to capture frame 437...
# Trying to capture frame 438...
# Trying to capture frame 439...
# Trying to capture frame 440...
# Trying to capture frame 441...
# Trying to capture frame 442...
# Trying to capture frame 443...
# Trying to capture frame 444...
# Trying to capture frame 445...
# Trying to capture frame 446...
# Trying to capture frame 447...
# Trying to capture frame 448...
# Trying to capture frame 449...
# Trying to capture frame 450...
# Trying to capture frame 451...
# Trying to capture frame 452...
# Trying to capture frame 453...
# Trying to capture frame 454...
# Trying to capture frame 455...
# Trying to capture frame 456...
# Trying to capture frame 457...
# Trying to capture frame 458...
# Trying to capture frame 459...
# Trying to capture frame 460...
# Trying to capture frame 461...
# Trying to capture frame 462...
# Trying to capture frame 463...
# Trying to capture frame 464...
# Trying to capture frame 465...
# Trying to capture frame 466...
# Trying to capture frame 467...
# Trying to capture frame 468...
# Trying to capture frame 469...
# Trying to capture frame 470...
# Trying to capture frame 471...
# Trying to capture frame 472...
# Trying to capture frame 473...
# Trying to capture frame 474...
# Trying to capture frame 475...
# Trying to capture frame 476...
# Captured!
# Trying to capture frame 477...
# Trying to capture frame 478...
# Trying to capture frame 479...
# Trying to capture frame 480...
# Trying to capture frame 481...
# Trying to capture frame 482...
# Trying to capture frame 483...
# Captured!
# Trying to capture frame 484...
# Trying to capture frame 485...
# Trying to capture frame 486...
# Trying to capture frame 487...
# Trying to capture frame 488...
# Trying to capture frame 489...
# Trying to capture frame 490...
# Trying to capture frame 491...
# Captured!
# Trying to capture frame 492...
# Trying to capture frame 493...
# Trying to capture frame 494...
# Trying to capture frame 495...
# Trying to capture frame 496...
# Trying to capture frame 497...
# Trying to capture frame 498...
# Trying to capture frame 499...
# Trying to capture frame 500...
# Trying to capture frame 501...
# Trying to capture frame 502...
# Trying to capture frame 503...
# Trying to capture frame 504...
# Trying to capture frame 505...
# Trying to capture frame 506...
# Trying to capture frame 507...
# Trying to capture frame 508...
# Trying to capture frame 509...
# Trying to capture frame 510...
# Trying to capture frame 511...
# Trying to capture frame 512...
# Trying to capture frame 513...
# Trying to capture frame 514...
# Trying to capture frame 515...
# Trying to capture frame 516...
# Trying to capture frame 517...
# Trying to capture frame 518...
# Trying to capture frame 519...
# Trying to capture frame 520...
# Trying to capture frame 521...
# Trying to capture frame 522...
# Trying to capture frame 523...
# Trying to capture frame 524...
# Trying to capture frame 525...
# Trying to capture frame 526...
# Trying to capture frame 527...
# Trying to capture frame 528...
# Trying to capture frame 529...
# Trying to capture frame 530...
# Trying to capture frame 531...
# Trying to capture frame 532...
# Trying to capture frame 533...
# Trying to capture frame 534...
# Trying to capture frame 535...
# Trying to capture frame 536...
# Trying to capture frame 537...
# Trying to capture frame 538...
# Trying to capture frame 539...
# Trying to capture frame 540...
# Trying to capture frame 541...
# Trying to capture frame 542...
# Trying to capture frame 543...
# Trying to capture frame 544...
# Trying to capture frame 545...
# Trying to capture frame 546...
# Trying to capture frame 547...
# Trying to capture frame 548...
# Trying to capture frame 549...
# Trying to capture frame 550...
# Trying to capture frame 551...
# Trying to capture frame 552...
# Trying to capture frame 553...
# Trying to capture frame 554...
# Trying to capture frame 555...
# Trying to capture frame 556...
# Trying to capture frame 557...
# Captured!
# Trying to capture frame 558...
# Trying to capture frame 559...
# Captured!
# Trying to capture frame 560...
# Trying to capture frame 561...
# Trying to capture frame 562...
# Trying to capture frame 563...
# Trying to capture frame 564...
# Trying to capture frame 565...
# Trying to capture frame 566...
# Trying to capture frame 567...
# Captured!
# Trying to capture frame 568...
# Trying to capture frame 569...
# Trying to capture frame 570...
# Trying to capture frame 571...
# Trying to capture frame 572...
# Trying to capture frame 573...
# Trying to capture frame 574...
# Captured!
# Trying to capture frame 575...
# Captured!
# Trying to capture frame 576...
# Captured!
# Trying to capture frame 577...
# Captured!
# Trying to capture frame 578...
# Captured!
# Trying to capture frame 579...
# Captured!
# Trying to capture frame 580...
# Trying to capture frame 581...
# Trying to capture frame 582...
# Trying to capture frame 583...
# Trying to capture frame 584...
# Trying to capture frame 585...
# Trying to capture frame 586...
# Trying to capture frame 587...
# Trying to capture frame 588...
# Trying to capture frame 589...
# Captured!
# Trying to capture frame 590...
# Captured!
# Trying to capture frame 591...
# Trying to capture frame 592...
# Trying to capture frame 593...
# Captured!
# Trying to capture frame 594...
# Trying to capture frame 595...
# Trying to capture frame 596...
# Trying to capture frame 597...
# Trying to capture frame 598...
# Trying to capture frame 599...
# Trying to capture frame 600...
# Trying to capture frame 601...
# Trying to capture frame 602...
# Trying to capture frame 603...
# Trying to capture frame 604...
# Trying to capture frame 605...
# Trying to capture frame 606...
# Trying to capture frame 607...
# Trying to capture frame 608...
# Trying to capture frame 609...
# Trying to capture frame 610...
# Trying to capture frame 611...
# Trying to capture frame 612...
# Trying to capture frame 613...
# Trying to capture frame 614...
# Trying to capture frame 615...
# Trying to capture frame 616...
# Trying to capture frame 617...
# Trying to capture frame 618...
# Trying to capture frame 619...
# Trying to capture frame 620...
# Trying to capture frame 621...
# Trying to capture frame 622...
# Trying to capture frame 623...
# Trying to capture frame 624...
# Trying to capture frame 625...
# Trying to capture frame 626...
# Trying to capture frame 627...
# Trying to capture frame 628...
# Trying to capture frame 629...
# Trying to capture frame 630...
# Trying to capture frame 631...
# Trying to capture frame 632...
# Trying to capture frame 633...
# Trying to capture frame 634...
# Trying to capture frame 635...
# Trying to capture frame 636...
# Trying to capture frame 637...
# Trying to capture frame 638...
# Trying to capture frame 639...
# Trying to capture frame 640...
# Trying to capture frame 641...
# Trying to capture frame 642...
# Trying to capture frame 643...
# Trying to capture frame 644...
# Trying to capture frame 645...
# Trying to capture frame 646...
# Trying to capture frame 647...
# Trying to capture frame 648...
# Trying to capture frame 649...
# Trying to capture frame 650...
# Trying to capture frame 651...
# Trying to capture frame 652...
# Trying to capture frame 653...
# Trying to capture frame 654...
# Trying to capture frame 655...
# Trying to capture frame 656...
# Trying to capture frame 657...
# Trying to capture frame 658...
# Trying to capture frame 659...
# Trying to capture frame 660...
# Trying to capture frame 661...
# Trying to capture frame 662...
# Trying to capture frame 663...
# Trying to capture frame 664...
# Trying to capture frame 665...
# Trying to capture frame 666...
# Trying to capture frame 667...
# Trying to capture frame 668...
# Trying to capture frame 669...
# Trying to capture frame 670...
# Trying to capture frame 671...
# Trying to capture frame 672...
# Trying to capture frame 673...
# Trying to capture frame 674...
# Trying to capture frame 675...
# Trying to capture frame 676...
# Trying to capture frame 677...
# Trying to capture frame 678...
# Trying to capture frame 679...
# Trying to capture frame 680...
# Trying to capture frame 681...
# Trying to capture frame 682...
# Trying to capture frame 683...
# Trying to capture frame 684...
# Trying to capture frame 685...
# Trying to capture frame 686...
# Trying to capture frame 687...
# Trying to capture frame 688...
# Trying to capture frame 689...
# Captured!
# Trying to capture frame 690...
# Captured!
# Trying to capture frame 691...
# Captured!
# Trying to capture frame 692...
# Trying to capture frame 693...
# Trying to capture frame 694...
# Trying to capture frame 695...
# Trying to capture frame 696...
# Trying to capture frame 697...
# Trying to capture frame 698...
# Captured!
# Trying to capture frame 699...
# Trying to capture frame 700...
# Trying to capture frame 701...
# Trying to capture frame 702...
# Captured!
# Trying to capture frame 703...
# Trying to capture frame 704...
# Trying to capture frame 705...
# Trying to capture frame 706...
# Trying to capture frame 707...
# Trying to capture frame 708...
# Trying to capture frame 709...
# Captured!
# Trying to capture frame 710...
# Captured!
# Trying to capture frame 711...
# Captured!
# Trying to capture frame 712...
# Captured!
# Trying to capture frame 713...
# Trying to capture frame 714...
# Trying to capture frame 715...
# Trying to capture frame 716...
# Trying to capture frame 717...
# Trying to capture frame 718...
# Trying to capture frame 719...
# Trying to capture frame 720...
# Trying to capture frame 721...
# Trying to capture frame 722...
# Trying to capture frame 723...
# Trying to capture frame 724...
# Trying to capture frame 725...
# Trying to capture frame 726...
# Trying to capture frame 727...
# Trying to capture frame 728...
# Trying to capture frame 729...
# Trying to capture frame 730...
# Trying to capture frame 731...
# Trying to capture frame 732...
# Trying to capture frame 733...
# Trying to capture frame 734...
# Trying to capture frame 735...
# Trying to capture frame 736...
# Trying to capture frame 737...
# Trying to capture frame 738...
# Trying to capture frame 739...
# Trying to capture frame 740...
# Trying to capture frame 741...
# Trying to capture frame 742...
# Trying to capture frame 743...
# Trying to capture frame 744...
# Trying to capture frame 745...
# Trying to capture frame 746...
# Trying to capture frame 747...
# Trying to capture frame 748...
# Captured!
# Trying to capture frame 749...
# Captured!
# Trying to capture frame 750...
# Captured!
# Trying to capture frame 751...
# Captured!
# Trying to capture frame 752...
# Trying to capture frame 753...
# Captured!
# Trying to capture frame 754...
# Trying to capture frame 755...
# Trying to capture frame 756...
# Captured!
# Trying to capture frame 757...
# Captured!
# Trying to capture frame 758...
# Trying to capture frame 759...
# Trying to capture frame 760...
# Trying to capture frame 761...
# Trying to capture frame 762...
# Trying to capture frame 763...
# Trying to capture frame 764...
# Trying to capture frame 765...
# Trying to capture frame 766...
# Trying to capture frame 767...
# Trying to capture frame 768...
# Captured!
# Trying to capture frame 769...
# Captured!
# Trying to capture frame 770...
# Captured!
# Trying to capture frame 771...
# Trying to capture frame 772...
# Captured!
# Trying to capture frame 773...
# Captured!
# Trying to capture frame 774...
# Captured!
# Trying to capture frame 775...
# Captured!
# Trying to capture frame 776...
# Captured!
# Trying to capture frame 777...
# Captured!
# Trying to capture frame 778...
# Captured!
# Trying to capture frame 779...
# Captured!
# Trying to capture frame 780...
# Captured!
# Trying to capture frame 781...
# Captured!
# Trying to capture frame 782...
# Trying to capture frame 783...
# Trying to capture frame 784...
# Trying to capture frame 785...
# Trying to capture frame 786...
# Trying to capture frame 787...
# Trying to capture frame 788...
# Trying to capture frame 789...
# Trying to capture frame 790...
# Trying to capture frame 791...
# Trying to capture frame 792...
# Trying to capture frame 793...
# Trying to capture frame 794...
# Trying to capture frame 795...
# Trying to capture frame 796...
# Trying to capture frame 797...
# Trying to capture frame 798...
# Trying to capture frame 799...
# Trying to capture frame 800...
# Trying to capture frame 801...
# Trying to capture frame 802...
# Trying to capture frame 803...
# Trying to capture frame 804...
# Trying to capture frame 805...
# Trying to capture frame 806...
# Trying to capture frame 807...
# Captured!
# Trying to capture frame 808...
# Trying to capture frame 809...
# Trying to capture frame 810...
# Trying to capture frame 811...
# Trying to capture frame 812...
# Trying to capture frame 813...
# Trying to capture frame 814...
# Trying to capture frame 815...
# Trying to capture frame 816...
# Trying to capture frame 817...
# Trying to capture frame 818...
# Trying to capture frame 819...
# Trying to capture frame 820...
# Trying to capture frame 821...
# Trying to capture frame 822...
# Trying to capture frame 823...
# Trying to capture frame 824...
# Trying to capture frame 825...
# Trying to capture frame 826...
# Trying to capture frame 827...
# Trying to capture frame 828...
# Trying to capture frame 829...
# Trying to capture frame 830...
# Trying to capture frame 831...
# Trying to capture frame 832...
# Trying to capture frame 833...
# Trying to capture frame 834...
# Trying to capture frame 835...
# Trying to capture frame 836...
# Trying to capture frame 837...
# Trying to capture frame 838...
# Trying to capture frame 839...
# Trying to capture frame 840...
# Trying to capture frame 841...
# Captured!
# Trying to capture frame 842...
# Trying to capture frame 843...
# Trying to capture frame 844...
# Trying to capture frame 845...
# Trying to capture frame 846...
# Trying to capture frame 847...
# Trying to capture frame 848...
# Trying to capture frame 849...
# Trying to capture frame 850...
# Trying to capture frame 851...
# Trying to capture frame 852...
# Trying to capture frame 853...
# Trying to capture frame 854...
# Trying to capture frame 855...
# Trying to capture frame 856...
# Trying to capture frame 857...
# Trying to capture frame 858...
# Trying to capture frame 859...
# Trying to capture frame 860...
# Trying to capture frame 861...
# Trying to capture frame 862...
# Trying to capture frame 863...
# Trying to capture frame 864...
# Trying to capture frame 865...
# Trying to capture frame 866...
# Trying to capture frame 867...
# Trying to capture frame 868...
# Trying to capture frame 869...
# Trying to capture frame 870...
# Trying to capture frame 871...
# Trying to capture frame 872...
# Trying to capture frame 873...
# Trying to capture frame 874...
# Trying to capture frame 875...
# Trying to capture frame 876...
# Trying to capture frame 877...
# Trying to capture frame 878...
# Trying to capture frame 879...
# Trying to capture frame 880...
# Trying to capture frame 881...
# Trying to capture frame 882...
# Trying to capture frame 883...
# Trying to capture frame 884...
# Trying to capture frame 885...
# Trying to capture frame 886...
# Trying to capture frame 887...
# Trying to capture frame 888...
# Trying to capture frame 889...
# Trying to capture frame 890...
# Trying to capture frame 891...
# Trying to capture frame 892...
# Trying to capture frame 893...
# Trying to capture frame 894...
# Trying to capture frame 895...
# Trying to capture frame 896...
# Trying to capture frame 897...
# Trying to capture frame 898...
# Trying to capture frame 899...
# Trying to capture frame 900...
# Trying to capture frame 901...
# Trying to capture frame 902...
# Trying to capture frame 903...
# Trying to capture frame 904...
# Trying to capture frame 905...
# Trying to capture frame 906...
# Trying to capture frame 907...
# Trying to capture frame 908...
# Trying to capture frame 909...
# Trying to capture frame 910...
# Trying to capture frame 911...
# Captured!
# Trying to capture frame 912...
# Captured!
# Trying to capture frame 913...
# Captured!
# Trying to capture frame 914...
# Captured!
# Trying to capture frame 915...
# Captured!
# Trying to capture frame 916...
# Captured!
# Trying to capture frame 917...
# Captured!
# Trying to capture frame 918...
# Captured!
# Trying to capture frame 919...
# Captured!
# Trying to capture frame 920...
# Captured!
# Trying to capture frame 921...
# Captured!
# Trying to capture frame 922...
# Captured!
# Trying to capture frame 923...
# Captured!
# Trying to capture frame 924...
# Captured!
# Trying to capture frame 925...
# Captured!
# Trying to capture frame 926...
# Captured!
# Trying to capture frame 927...
# Captured!
# Trying to capture frame 928...
# Captured!
# Trying to capture frame 929...
# Captured!
# Trying to capture frame 930...
# Captured!
# Trying to capture frame 931...
# Trying to capture frame 932...
# Captured!
# Trying to capture frame 933...
# Trying to capture frame 934...
# Trying to capture frame 935...
# Trying to capture frame 936...
# Captured!
# Trying to capture frame 937...
# Captured!
# Trying to capture frame 938...
# Trying to capture frame 939...
# Trying to capture frame 940...
# Trying to capture frame 941...
# Trying to capture frame 942...
# Trying to capture frame 943...
# Trying to capture frame 944...
# Trying to capture frame 945...
# Trying to capture frame 946...
# Trying to capture frame 947...
# Trying to capture frame 948...
# Trying to capture frame 949...
# Trying to capture frame 950...
# Trying to capture frame 951...
# Trying to capture frame 952...
# Trying to capture frame 953...
# Trying to capture frame 954...
# Trying to capture frame 955...
# Captured!
# Trying to capture frame 956...
# Trying to capture frame 957...
# Trying to capture frame 958...
# Trying to capture frame 959...
# Trying to capture frame 960...
# Trying to capture frame 961...
# Trying to capture frame 962...
# Trying to capture frame 963...
# Trying to capture frame 964...
# Trying to capture frame 965...
# Trying to capture frame 966...
# Trying to capture frame 967...
# Trying to capture frame 968...
# Captured!
# Trying to capture frame 969...
# Captured!
# Trying to capture frame 970...
# Trying to capture frame 971...
# Trying to capture frame 972...
# Trying to capture frame 973...
# Trying to capture frame 974...
# Trying to capture frame 975...
# Trying to capture frame 976...
# Trying to capture frame 977...
# Trying to capture frame 978...
# Trying to capture frame 979...
# Trying to capture frame 980...
# Trying to capture frame 981...
# Trying to capture frame 982...
# Trying to capture frame 983...
# Trying to capture frame 984...
# Trying to capture frame 985...
# Trying to capture frame 986...
# Trying to capture frame 987...
# Trying to capture frame 988...
# Trying to capture frame 989...
# Trying to capture frame 990...
# Trying to capture frame 991...
# Trying to capture frame 992...
# Trying to capture frame 993...
# Trying to capture frame 994...
# Captured!
# Trying to capture frame 995...
# Captured!
# Trying to capture frame 996...
# Captured!
# Trying to capture frame 997...
# Trying to capture frame 998...
# Trying to capture frame 999...
# Trying to capture frame 1000...
# Trying to capture frame 1001...
# Trying to capture frame 1002...
# Trying to capture frame 1003...
# Trying to capture frame 1004...
# Trying to capture frame 1005...
# Trying to capture frame 1006...
# Trying to capture frame 1007...
# Trying to capture frame 1008...
# Trying to capture frame 1009...
# Trying to capture frame 1010...
# Trying to capture frame 1011...
# Trying to capture frame 1012...
# Trying to capture frame 1013...
# Trying to capture frame 1014...
# Trying to capture frame 1015...
# Trying to capture frame 1016...
# Trying to capture frame 1017...
# Trying to capture frame 1018...
# Trying to capture frame 1019...
# Trying to capture frame 1020...
# Trying to capture frame 1021...
# Trying to capture frame 1022...
# Captured!
# Trying to capture frame 1023...
# Trying to capture frame 1024...
# Trying to capture frame 1025...
# Captured!
# Trying to capture frame 1026...
# Captured!
# Trying to capture frame 1027...
# Trying to capture frame 1028...
# Trying to capture frame 1029...
# Trying to capture frame 1030...
# Trying to capture frame 1031...
# Trying to capture frame 1032...
# Trying to capture frame 1033...
# Trying to capture frame 1034...
# Trying to capture frame 1035...
# Captured!
# Trying to capture frame 1036...
# Captured!
# Trying to capture frame 1037...
# Captured!
# Trying to capture frame 1038...
# Captured!
# Trying to capture frame 1039...
# Captured!
# Trying to capture frame 1040...
# Captured!
# Trying to capture frame 1041...
# Trying to capture frame 1042...
# Captured!
# Trying to capture frame 1043...
# Captured!
# Trying to capture frame 1044...
# Trying to capture frame 1045...
# Trying to capture frame 1046...
# Trying to capture frame 1047...
# Trying to capture frame 1048...
# Trying to capture frame 1049...
# Trying to capture frame 1050...
# Trying to capture frame 1051...
# Trying to capture frame 1052...
# Trying to capture frame 1053...
# Trying to capture frame 1054...
# Trying to capture frame 1055...
# Trying to capture frame 1056...
# Trying to capture frame 1057...
# Trying to capture frame 1058...
# Trying to capture frame 1059...
# Trying to capture frame 1060...
# Trying to capture frame 1061...
# Trying to capture frame 1062...
# Trying to capture frame 1063...
# Trying to capture frame 1064...
# Trying to capture frame 1065...
# Trying to capture frame 1066...
# Trying to capture frame 1067...
# Trying to capture frame 1068...
# Trying to capture frame 1069...
# Trying to capture frame 1070...
# Trying to capture frame 1071...
# Trying to capture frame 1072...
# Trying to capture frame 1073...
# Trying to capture frame 1074...
# Trying to capture frame 1075...
# Trying to capture frame 1076...
# Trying to capture frame 1077...
# Trying to capture frame 1078...
# Trying to capture frame 1079...
# Trying to capture frame 1080...
# Trying to capture frame 1081...
# Trying to capture frame 1082...
# Trying to capture frame 1083...
# Trying to capture frame 1084...
# Trying to capture frame 1085...
# Trying to capture frame 1086...
# Trying to capture frame 1087...
# Trying to capture frame 1088...
# Trying to capture frame 1089...
# Trying to capture frame 1090...
# Trying to capture frame 1091...
# Trying to capture frame 1092...
# Trying to capture frame 1093...
# Trying to capture frame 1094...
# Trying to capture frame 1095...
# Trying to capture frame 1096...
# Trying to capture frame 1097...
# Trying to capture frame 1098...
# Trying to capture frame 1099...
# Trying to capture frame 1100...
# Trying to capture frame 1101...
# Trying to capture frame 1102...
# Trying to capture frame 1103...
# Trying to capture frame 1104...
# Trying to capture frame 1105...
# Trying to capture frame 1106...
# Trying to capture frame 1107...
# Trying to capture frame 1108...
# Trying to capture frame 1109...
# Trying to capture frame 1110...
# Trying to capture frame 1111...
# Trying to capture frame 1112...
# Trying to capture frame 1113...
# Trying to capture frame 1114...
# Trying to capture frame 1115...
# Trying to capture frame 1116...
# Trying to capture frame 1117...
# Trying to capture frame 1118...
# Trying to capture frame 1119...
# Trying to capture frame 1120...
# Trying to capture frame 1121...
# Trying to capture frame 1122...
# Trying to capture frame 1123...
# Trying to capture frame 1124...
# Trying to capture frame 1125...
# Trying to capture frame 1126...
# Trying to capture frame 1127...
# Trying to capture frame 1128...
# Trying to capture frame 1129...
# Trying to capture frame 1130...
# Trying to capture frame 1131...
# Trying to capture frame 1132...
# Trying to capture frame 1133...
# Trying to capture frame 1134...
# Trying to capture frame 1135...
# Trying to capture frame 1136...
# Trying to capture frame 1137...
# Trying to capture frame 1138...
# Trying to capture frame 1139...
# Trying to capture frame 1140...
# Trying to capture frame 1141...
# Trying to capture frame 1142...
# Trying to capture frame 1143...
# Trying to capture frame 1144...
# Trying to capture frame 1145...
# Trying to capture frame 1146...
# Trying to capture frame 1147...
# Trying to capture frame 1148...
# Trying to capture frame 1149...
# Trying to capture frame 1150...
# Trying to capture frame 1151...
# Trying to capture frame 1152...
# Trying to capture frame 1153...
# Trying to capture frame 1154...
# Trying to capture frame 1155...
# Trying to capture frame 1156...
# Trying to capture frame 1157...
# Trying to capture frame 1158...
# Trying to capture frame 1159...
# Trying to capture frame 1160...
# Trying to capture frame 1161...
# Trying to capture frame 1162...
# Trying to capture frame 1163...
# Trying to capture frame 1164...
# Trying to capture frame 1165...
# Trying to capture frame 1166...
# Trying to capture frame 1167...
# Trying to capture frame 1168...
# Trying to capture frame 1169...
# Trying to capture frame 1170...
# Trying to capture frame 1171...
# Trying to capture frame 1172...
# Trying to capture frame 1173...
# Trying to capture frame 1174...
# Trying to capture frame 1175...
# Trying to capture frame 1176...
# Trying to capture frame 1177...
# Trying to capture frame 1178...
# Trying to capture frame 1179...
# Trying to capture frame 1180...
# Trying to capture frame 1181...
# Trying to capture frame 1182...
# Trying to capture frame 1183...
# Trying to capture frame 1184...
# Trying to capture frame 1185...
# Trying to capture frame 1186...
# Trying to capture frame 1187...
# Trying to capture frame 1188...
# Trying to capture frame 1189...
# Trying to capture frame 1190...
# Trying to capture frame 1191...
# Trying to capture frame 1192...
# Trying to capture frame 1193...
# Trying to capture frame 1194...
# Trying to capture frame 1195...
# Trying to capture frame 1196...
# Trying to capture frame 1197...
# Trying to capture frame 1198...
# Trying to capture frame 1199...
# Trying to capture frame 1200...
# Trying to capture frame 1201...
# Trying to capture frame 1202...
# Trying to capture frame 1203...
# Trying to capture frame 1204...
# Trying to capture frame 1205...
# Trying to capture frame 1206...
# Trying to capture frame 1207...
# Trying to capture frame 1208...
# Trying to capture frame 1209...
# Trying to capture frame 1210...
# Trying to capture frame 1211...
# Trying to capture frame 1212...
# Trying to capture frame 1213...
# Trying to capture frame 1214...
# Trying to capture frame 1215...
# Trying to capture frame 1216...
# Trying to capture frame 1217...
# Trying to capture frame 1218...
# Trying to capture frame 1219...
# Trying to capture frame 1220...
# Trying to capture frame 1221...
# Trying to capture frame 1222...
# Trying to capture frame 1223...
# Trying to capture frame 1224...
# Trying to capture frame 1225...
# Trying to capture frame 1226...
# Trying to capture frame 1227...
# Trying to capture frame 1228...
# Trying to capture frame 1229...
# Trying to capture frame 1230...
# Trying to capture frame 1231...
# Trying to capture frame 1232...
# Trying to capture frame 1233...
# Trying to capture frame 1234...
# Trying to capture frame 1235...
# Trying to capture frame 1236...
# Trying to capture frame 1237...
# Trying to capture frame 1238...
# Trying to capture frame 1239...
# Trying to capture frame 1240...
# Trying to capture frame 1241...
# Trying to capture frame 1242...
# Trying to capture frame 1243...
# Trying to capture frame 1244...
# Trying to capture frame 1245...
# Trying to capture frame 1246...
# Trying to capture frame 1247...
# Trying to capture frame 1248...
# Trying to capture frame 1249...
# Trying to capture frame 1250...
# Trying to capture frame 1251...
# Trying to capture frame 1252...
# Trying to capture frame 1253...
# Trying to capture frame 1254...
# Trying to capture frame 1255...
# Trying to capture frame 1256...
# Captured!
# Trying to capture frame 1257...
# Trying to capture frame 1258...
# Trying to capture frame 1259...
# Trying to capture frame 1260...
# Trying to capture frame 1261...
# Trying to capture frame 1262...
# Trying to capture frame 1263...
# Trying to capture frame 1264...
# Trying to capture frame 1265...
# Trying to capture frame 1266...
# Trying to capture frame 1267...
# Trying to capture frame 1268...
# Trying to capture frame 1269...
# Trying to capture frame 1270...
# Trying to capture frame 1271...
# Trying to capture frame 1272...
# Trying to capture frame 1273...
# Trying to capture frame 1274...
# Trying to capture frame 1275...
# Trying to capture frame 1276...
# Trying to capture frame 1277...
# Trying to capture frame 1278...
# Trying to capture frame 1279...
# Captured!
# Trying to capture frame 1280...
# Trying to capture frame 1281...
# Trying to capture frame 1282...
# Trying to capture frame 1283...
# Trying to capture frame 1284...
# Trying to capture frame 1285...
# Captured!
# Trying to capture frame 1286...
# Captured!
# Trying to capture frame 1287...
# Captured!
# Trying to capture frame 1288...
# Captured!
# Trying to capture frame 1289...
# Captured!
# Trying to capture frame 1290...
# Captured!
# Trying to capture frame 1291...
# Captured!
# Trying to capture frame 1292...
# Trying to capture frame 1293...
# Trying to capture frame 1294...
# Trying to capture frame 1295...
# Trying to capture frame 1296...
# Trying to capture frame 1297...
# Trying to capture frame 1298...
# Trying to capture frame 1299...
# Trying to capture frame 1300...
# Trying to capture frame 1301...
# Trying to capture frame 1302...
# Trying to capture frame 1303...
# Trying to capture frame 1304...
# Trying to capture frame 1305...
# Trying to capture frame 1306...
# Trying to capture frame 1307...
# Trying to capture frame 1308...
# Trying to capture frame 1309...
# Trying to capture frame 1310...
# Trying to capture frame 1311...
# Trying to capture frame 1312...
# Captured!
# Trying to capture frame 1313...
# Captured!
# Trying to capture frame 1314...
# Trying to capture frame 1315...
# Trying to capture frame 1316...
# Trying to capture frame 1317...
# Trying to capture frame 1318...
# Trying to capture frame 1319...
# Trying to capture frame 1320...
# Trying to capture frame 1321...
# Trying to capture frame 1322...
# Trying to capture frame 1323...
# Trying to capture frame 1324...
# Trying to capture frame 1325...
# Trying to capture frame 1326...
# Trying to capture frame 1327...
# Trying to capture frame 1328...
# Trying to capture frame 1329...
# Trying to capture frame 1330...
# Trying to capture frame 1331...
# Trying to capture frame 1332...
# Trying to capture frame 1333...
# Trying to capture frame 1334...
# Trying to capture frame 1335...
# Trying to capture frame 1336...
# Trying to capture frame 1337...
# Trying to capture frame 1338...
# Trying to capture frame 1339...
# Trying to capture frame 1340...
# Captured!
# Trying to capture frame 1341...
# Captured!
# Trying to capture frame 1342...
# Captured!
# Trying to capture frame 1343...
# Trying to capture frame 1344...
# Captured!
# Trying to capture frame 1345...
# Trying to capture frame 1346...
# Trying to capture frame 1347...
# Trying to capture frame 1348...
# Trying to capture frame 1349...
# Captured!
# Trying to capture frame 1350...
# Captured!
# Trying to capture frame 1351...
# Trying to capture frame 1352...
# Trying to capture frame 1353...
# Trying to capture frame 1354...
# Trying to capture frame 1355...
# Trying to capture frame 1356...
# Trying to capture frame 1357...
# Trying to capture frame 1358...
# Trying to capture frame 1359...
# Trying to capture frame 1360...
# Trying to capture frame 1361...
# Trying to capture frame 1362...
# Trying to capture frame 1363...
# Trying to capture frame 1364...
# Trying to capture frame 1365...
# Trying to capture frame 1366...
# Trying to capture frame 1367...
# Trying to capture frame 1368...
# Trying to capture frame 1369...
# Trying to capture frame 1370...
# Trying to capture frame 1371...
# Trying to capture frame 1372...
# Trying to capture frame 1373...
# Trying to capture frame 1374...
# Trying to capture frame 1375...
# Trying to capture frame 1376...
# Trying to capture frame 1377...
# Trying to capture frame 1378...
# Trying to capture frame 1379...
# Trying to capture frame 1380...
# Trying to capture frame 1381...
# Trying to capture frame 1382...
# Trying to capture frame 1383...
# Trying to capture frame 1384...
# Trying to capture frame 1385...
# Trying to capture frame 1386...
# Trying to capture frame 1387...
# Trying to capture frame 1388...
# Trying to capture frame 1389...
# Trying to capture frame 1390...
# Trying to capture frame 1391...
# Trying to capture frame 1392...
# Trying to capture frame 1393...
# Trying to capture frame 1394...
# Trying to capture frame 1395...
# Trying to capture frame 1396...
# Trying to capture frame 1397...
# Trying to capture frame 1398...
# Trying to capture frame 1399...
# Trying to capture frame 1400...
# Trying to capture frame 1401...
# Trying to capture frame 1402...
# Trying to capture frame 1403...
# Trying to capture frame 1404...
# Trying to capture frame 1405...
# Trying to capture frame 1406...
# Trying to capture frame 1407...
# Trying to capture frame 1408...
# Trying to capture frame 1409...
# Trying to capture frame 1410...
# Trying to capture frame 1411...
# Trying to capture frame 1412...
# Trying to capture frame 1413...
# Trying to capture frame 1414...
# Trying to capture frame 1415...
# Trying to capture frame 1416...
# Trying to capture frame 1417...
# Trying to capture frame 1418...
# Trying to capture frame 1419...
# Trying to capture frame 1420...
# Trying to capture frame 1421...
# Trying to capture frame 1422...
# Trying to capture frame 1423...
# Trying to capture frame 1424...
# Trying to capture frame 1425...
# Trying to capture frame 1426...
# Trying to capture frame 1427...
# Trying to capture frame 1428...
# Trying to capture frame 1429...
# Trying to capture frame 1430...
# Trying to capture frame 1431...
# Trying to capture frame 1432...
# Trying to capture frame 1433...
# Trying to capture frame 1434...
# Trying to capture frame 1435...
# Trying to capture frame 1436...
# Trying to capture frame 1437...
# Trying to capture frame 1438...
# Trying to capture frame 1439...
# Trying to capture frame 1440...
# Trying to capture frame 1441...
# Trying to capture frame 1442...
# Trying to capture frame 1443...
# Trying to capture frame 1444...
# Trying to capture frame 1445...
# Trying to capture frame 1446...
# Trying to capture frame 1447...
# Trying to capture frame 1448...
# Trying to capture frame 1449...
# Trying to capture frame 1450...
# Trying to capture frame 1451...
# Trying to capture frame 1452...
# Trying to capture frame 1453...
# Trying to capture frame 1454...
# Trying to capture frame 1455...
# Trying to capture frame 1456...
# Trying to capture frame 1457...
# Trying to capture frame 1458...
# Trying to capture frame 1459...
# Trying to capture frame 1460...
# Trying to capture frame 1461...
# Trying to capture frame 1462...
# Trying to capture frame 1463...
# Trying to capture frame 1464...
# Trying to capture frame 1465...
# Trying to capture frame 1466...
# Trying to capture frame 1467...
# Trying to capture frame 1468...
# Trying to capture frame 1469...
# Trying to capture frame 1470...
# Trying to capture frame 1471...
# Trying to capture frame 1472...
# Trying to capture frame 1473...
# Trying to capture frame 1474...
# Trying to capture frame 1475...
# Trying to capture frame 1476...
# Trying to capture frame 1477...
# Trying to capture frame 1478...
# Trying to capture frame 1479...
# Trying to capture frame 1480...
# Trying to capture frame 1481...
# Trying to capture frame 1482...
# Trying to capture frame 1483...
# Trying to capture frame 1484...
# Trying to capture frame 1485...
# Trying to capture frame 1486...
# Trying to capture frame 1487...
# Trying to capture frame 1488...
# Trying to capture frame 1489...
# Trying to capture frame 1490...
# Trying to capture frame 1491...
# Trying to capture frame 1492...
# Trying to capture frame 1493...
# Trying to capture frame 1494...
# Trying to capture frame 1495...
# Trying to capture frame 1496...
# Total frame count: 1496
# 33 frame of landmarks captured
# Total frame count: 1496
# 33 frame of landmarks captured
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# ([array([[4.48430093e-09, 1.01707956e-22, 1.08314504e-17, 2.36827484e-03,
#           3.69704470e-17, 7.79899319e-23, 5.22663268e-17, 9.97631669e-01]],
#         dtype=float32),
#   array([[4.48430093e-09, 1.01707956e-22, 1.08314504e-17, 2.36827484e-03,
#           3.69704470e-17, 7.79899319e-23, 5.22663268e-17, 9.97631669e-01]],
#         dtype=float32),
#   array([[7.9598508e-21, 1.9515305e-29, 2.3106909e-24, 6.6140702e-13,
#           3.6523025e-28, 0.0000000e+00, 7.7323056e-36, 1.0000000e+00]],
#         dtype=float32),
#   array([[4.8657107e-06, 2.3555293e-22, 2.6039717e-16, 2.4188936e-03,
#           6.9179973e-17, 5.9586970e-20, 5.5619154e-10, 9.9757630e-01]],
#         dtype=float32),
#   array([[3.3228054e-15, 1.3063956e-32, 2.1026787e-33, 2.4097884e-16,
#           3.5941585e-27, 8.4379505e-31, 8.9746447e-25, 1.0000000e+00]],
#         dtype=float32),
#   array([[1.1883124e-06, 1.8832536e-20, 3.8105299e-16, 7.1000628e-05,
#           2.0429261e-21, 3.4668767e-26, 1.5389230e-17, 9.9992776e-01]],
#         dtype=float32),
#   array([[1.1883124e-06, 1.8832536e-20, 3.8105299e-16, 7.1000628e-05,
#           2.0429261e-21, 3.4668767e-26, 1.5389230e-17, 9.9992776e-01]],
#         dtype=float32),
#   array([[1.3717346e-11, 1.5665404e-22, 3.4136506e-20, 2.0059294e-04,
#           3.8998440e-23, 4.5086247e-27, 7.9209410e-21, 9.9979943e-01]],
#         dtype=float32),
#   array([[1.3717346e-11, 1.5665404e-22, 3.4136506e-20, 2.0059294e-04,
#           3.8998440e-23, 4.5086247e-27, 7.9209410e-21, 9.9979943e-01]],
#         dtype=float32),
#   array([[1.5854982e-19, 5.8163345e-09, 9.9928063e-01, 1.2071982e-08,
#           7.1924465e-04, 0.0000000e+00, 0.0000000e+00, 4.7865246e-08]],
#         dtype=float32),
#   array([[5.6792533e-22, 2.4210274e-09, 9.9993825e-01, 1.8405105e-09,
#           6.1777726e-05, 0.0000000e+00, 0.0000000e+00, 4.6565141e-10]],
#         dtype=float32),
#   array([[5.6792533e-22, 2.4210274e-09, 9.9993825e-01, 1.8405105e-09,
#           6.1777726e-05, 0.0000000e+00, 0.0000000e+00, 4.6565141e-10]],
#         dtype=float32),
#   array([[1.3151171e-03, 4.7694268e-35, 3.7480002e-14, 9.9667871e-01,
#           1.3210030e-06, 0.0000000e+00, 8.5539054e-05, 1.9192777e-03]],
#         dtype=float32),
#   array([[7.3922492e-28, 1.5838392e-27, 0.0000000e+00, 8.3539932e-19,
#           3.6232836e-29, 0.0000000e+00, 2.9092402e-34, 1.0000000e+00]],
#         dtype=float32),
#   array([[7.3922492e-28, 1.5838392e-27, 0.0000000e+00, 8.3539932e-19,
#           3.6232836e-29, 0.0000000e+00, 2.9092402e-34, 1.0000000e+00]],
#         dtype=float32),
#   array([[4.5249965e-15, 0.0000000e+00, 1.0906412e-29, 2.7610883e-15,
#           2.2820328e-13, 0.0000000e+00, 3.5611722e-12, 1.0000000e+00]],
#         dtype=float32),
#   array([[3.5038319e-10, 3.2996534e-33, 1.5463513e-18, 1.8137333e-17,
#           4.9331896e-03, 0.0000000e+00, 2.2561096e-01, 7.6945585e-01]],
#         dtype=float32),
#   array([[1.56176141e-10, 4.05409640e-27, 1.36886741e-22, 1.74493394e-22,
#           1.06789805e-04, 0.00000000e+00, 9.83437419e-01, 1.64558329e-02]],
#         dtype=float32),
#   array([[1.5976533e-06, 1.7213608e-34, 7.2951096e-17, 5.8696496e-06,
#           9.3534708e-01, 0.0000000e+00, 1.4865305e-02, 4.9780123e-02]],
#         dtype=float32),
#   array([[1.5976533e-06, 1.7213608e-34, 7.2951096e-17, 5.8696496e-06,
#           9.3534708e-01, 0.0000000e+00, 1.4865305e-02, 4.9780123e-02]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#           7.0124688e-36, 0.0000000e+00, 3.0144455e-16, 1.0000000e+00]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.0756008e-37,
#           1.4389179e-23, 0.0000000e+00, 1.6526585e-13, 1.0000000e+00]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.1575313e-34,
#           2.9419544e-24, 0.0000000e+00, 6.2621540e-11, 1.0000000e+00]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#           2.6130375e-24, 0.0000000e+00, 1.7856751e-21, 1.0000000e+00]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#           2.6130375e-24, 0.0000000e+00, 1.7856751e-21, 1.0000000e+00]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#           2.6130375e-24, 0.0000000e+00, 1.7856751e-21, 1.0000000e+00]],
#         dtype=float32),
#   array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#           2.6130375e-24, 0.0000000e+00, 1.7856751e-21, 1.0000000e+00]],
#         dtype=float32),
#   array([[1.5278780e-26, 8.6390024e-32, 1.3805206e-29, 7.0520370e-21,
#           5.9276418e-27, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00]],
#         dtype=float32),
#   array([[9.4465335e-08, 1.6912244e-29, 2.4170298e-13, 1.2122507e-04,
#           3.5668447e-04, 0.0000000e+00, 9.9947816e-01, 4.3879194e-05]],
#         dtype=float32),
#   array([[2.5604368e-15, 0.0000000e+00, 1.0543005e-26, 5.8755801e-16,
#           1.6847679e-18, 0.0000000e+00, 2.2465681e-20, 1.0000000e+00]],
#         dtype=float32),
#   array([[3.8606420e-09, 1.0471702e-26, 9.3025706e-13, 2.5742546e-09,
#           8.1926340e-04, 0.0000000e+00, 1.8177884e-07, 9.9918050e-01]],
#         dtype=float32),
#   array([[3.8606420e-09, 1.0471702e-26, 9.3025706e-13, 2.5742546e-09,
#           8.1926340e-04, 0.0000000e+00, 1.8177884e-07, 9.9918050e-01]],
#         dtype=float32),
#   array([[3.8606420e-09, 1.0471702e-26, 9.3025706e-13, 2.5742546e-09,
#           8.1926340e-04, 0.0000000e+00, 1.8177884e-07, 9.9918050e-01]],
#         dtype=float32)],
#  ['surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'disgust',
#   'disgust',
#   'disgust',
#   'fear',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'sad',
#   'happy',
#   'happy',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise',
#   'sad',
#   'surprise',
#   'surprise',
#   'surprise',
#   'surprise'])

# %% [markdown]
# ###Combine the outputs from two models

# %% [markdown]
# `predictions_dict = ['angry', 'calm', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']`

# %%
audio_prediction_vectors, audio_prediction_labels = audio_predict("/content/demo.wav")
visual_prediction_vectors, visual_prediction_labels = visual_predict(demo_path)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Parsing file <path: /content/demo.mp4>
# Trying to capture frame 1...
# Trying to capture frame 2...
# Trying to capture frame 3...
# Trying to capture frame 4...
# Trying to capture frame 5...
# Trying to capture frame 6...
# Trying to capture frame 7...
# Trying to capture frame 8...
# Trying to capture frame 9...
# Trying to capture frame 10...
# Trying to capture frame 11...
# Trying to capture frame 12...
# Trying to capture frame 13...
# Trying to capture frame 14...
# Trying to capture frame 15...
# Trying to capture frame 16...
# Trying to capture frame 17...
# Trying to capture frame 18...
# Trying to capture frame 19...
# Trying to capture frame 20...
# Trying to capture frame 21...
# Trying to capture frame 22...
# Trying to capture frame 23...
# Trying to capture frame 24...
# Trying to capture frame 25...
# Trying to capture frame 26...
# Trying to capture frame 27...
# Trying to capture frame 28...
# Trying to capture frame 29...
# Trying to capture frame 30...
# Trying to capture frame 31...
# Trying to capture frame 32...
# Trying to capture frame 33...
# Trying to capture frame 34...
# Trying to capture frame 35...
# Trying to capture frame 36...
# Trying to capture frame 37...
# Trying to capture frame 38...
# Trying to capture frame 39...
# Trying to capture frame 40...
# Trying to capture frame 41...
# Trying to capture frame 42...
# Trying to capture frame 43...
# Trying to capture frame 44...
# Trying to capture frame 45...
# Trying to capture frame 46...
# Trying to capture frame 47...
# Trying to capture frame 48...
# Trying to capture frame 49...
# Trying to capture frame 50...
# Trying to capture frame 51...
# Trying to capture frame 52...
# Trying to capture frame 53...
# Trying to capture frame 54...
# Trying to capture frame 55...
# Trying to capture frame 56...
# Trying to capture frame 57...
# Trying to capture frame 58...
# Trying to capture frame 59...
# Trying to capture frame 60...
# Trying to capture frame 61...
# Trying to capture frame 62...
# Trying to capture frame 63...
# Trying to capture frame 64...
# Trying to capture frame 65...
# Trying to capture frame 66...
# Trying to capture frame 67...
# Trying to capture frame 68...
# Trying to capture frame 69...
# Trying to capture frame 70...
# Trying to capture frame 71...
# Trying to capture frame 72...
# Trying to capture frame 73...
# Trying to capture frame 74...
# Trying to capture frame 75...
# Trying to capture frame 76...
# Trying to capture frame 77...
# Trying to capture frame 78...
# Trying to capture frame 79...
# Trying to capture frame 80...
# Trying to capture frame 81...
# Trying to capture frame 82...
# Trying to capture frame 83...
# Trying to capture frame 84...
# Trying to capture frame 85...
# Trying to capture frame 86...
# Trying to capture frame 87...
# Trying to capture frame 88...
# Trying to capture frame 89...
# Trying to capture frame 90...
# Trying to capture frame 91...
# Captured!
# Trying to capture frame 92...
# Captured!
# Trying to capture frame 93...
# Captured!
# Trying to capture frame 94...
# Captured!
# Trying to capture frame 95...
# Captured!
# Trying to capture frame 96...
# Trying to capture frame 97...
# Trying to capture frame 98...
# Trying to capture frame 99...
# Trying to capture frame 100...
# Trying to capture frame 101...
# Trying to capture frame 102...
# Trying to capture frame 103...
# Trying to capture frame 104...
# Trying to capture frame 105...
# Trying to capture frame 106...
# Trying to capture frame 107...
# Trying to capture frame 108...
# Trying to capture frame 109...
# Trying to capture frame 110...
# Trying to capture frame 111...
# Trying to capture frame 112...
# Trying to capture frame 113...
# Trying to capture frame 114...
# Trying to capture frame 115...
# Trying to capture frame 116...
# Trying to capture frame 117...
# Trying to capture frame 118...
# Trying to capture frame 119...
# Trying to capture frame 120...
# Trying to capture frame 121...
# Trying to capture frame 122...
# Trying to capture frame 123...
# Trying to capture frame 124...
# Captured!
# Trying to capture frame 125...
# Captured!
# Trying to capture frame 126...
# Captured!
# Trying to capture frame 127...
# Captured!
# Trying to capture frame 128...
# Captured!
# Trying to capture frame 129...
# Trying to capture frame 130...
# Trying to capture frame 131...
# Trying to capture frame 132...
# Trying to capture frame 133...
# Trying to capture frame 134...
# Trying to capture frame 135...
# Trying to capture frame 136...
# Trying to capture frame 137...
# Trying to capture frame 138...
# Trying to capture frame 139...
# Trying to capture frame 140...
# Trying to capture frame 141...
# Trying to capture frame 142...
# Trying to capture frame 143...
# Captured!
# Trying to capture frame 144...
# Trying to capture frame 145...
# Trying to capture frame 146...
# Trying to capture frame 147...
# Trying to capture frame 148...
# Trying to capture frame 149...
# Trying to capture frame 150...
# Trying to capture frame 151...
# Trying to capture frame 152...
# Trying to capture frame 153...
# Trying to capture frame 154...
# Trying to capture frame 155...
# Trying to capture frame 156...
# Trying to capture frame 157...
# Trying to capture frame 158...
# Trying to capture frame 159...
# Trying to capture frame 160...
# Trying to capture frame 161...
# Trying to capture frame 162...
# Trying to capture frame 163...
# Trying to capture frame 164...
# Trying to capture frame 165...
# Trying to capture frame 166...
# Trying to capture frame 167...
# Trying to capture frame 168...
# Trying to capture frame 169...
# Trying to capture frame 170...
# Trying to capture frame 171...
# Trying to capture frame 172...
# Trying to capture frame 173...
# Trying to capture frame 174...
# Trying to capture frame 175...
# Trying to capture frame 176...
# Trying to capture frame 177...
# Trying to capture frame 178...
# Trying to capture frame 179...
# Trying to capture frame 180...
# Trying to capture frame 181...
# Captured!
# Trying to capture frame 182...
# Captured!
# Trying to capture frame 183...
# Captured!
# Trying to capture frame 184...
# Captured!
# Trying to capture frame 185...
# Trying to capture frame 186...
# Trying to capture frame 187...
# Trying to capture frame 188...
# Trying to capture frame 189...
# Captured!
# Trying to capture frame 190...
# Captured!
# Trying to capture frame 191...
# Captured!
# Trying to capture frame 192...
# Captured!
# Trying to capture frame 193...
# Captured!
# Trying to capture frame 194...
# Trying to capture frame 195...
# Trying to capture frame 196...
# Captured!
# Trying to capture frame 197...
# Trying to capture frame 198...
# Captured!
# Trying to capture frame 199...
# Captured!
# Trying to capture frame 200...
# Trying to capture frame 201...
# Trying to capture frame 202...
# Trying to capture frame 203...
# Trying to capture frame 204...
# Trying to capture frame 205...
# Trying to capture frame 206...
# Trying to capture frame 207...
# Trying to capture frame 208...
# Trying to capture frame 209...
# Trying to capture frame 210...
# Trying to capture frame 211...
# Trying to capture frame 212...
# Trying to capture frame 213...
# Trying to capture frame 214...
# Trying to capture frame 215...
# Trying to capture frame 216...
# Trying to capture frame 217...
# Trying to capture frame 218...
# Trying to capture frame 219...
# Trying to capture frame 220...
# Trying to capture frame 221...
# Trying to capture frame 222...
# Trying to capture frame 223...
# Trying to capture frame 224...
# Trying to capture frame 225...
# Trying to capture frame 226...
# Trying to capture frame 227...
# Trying to capture frame 228...
# Trying to capture frame 229...
# Trying to capture frame 230...
# Trying to capture frame 231...
# Trying to capture frame 232...
# Trying to capture frame 233...
# Trying to capture frame 234...
# Trying to capture frame 235...
# Trying to capture frame 236...
# Trying to capture frame 237...
# Trying to capture frame 238...
# Trying to capture frame 239...
# Trying to capture frame 240...
# Trying to capture frame 241...
# Trying to capture frame 242...
# Trying to capture frame 243...
# Trying to capture frame 244...
# Trying to capture frame 245...
# Trying to capture frame 246...
# Trying to capture frame 247...
# Trying to capture frame 248...
# Trying to capture frame 249...
# Trying to capture frame 250...
# Trying to capture frame 251...
# Trying to capture frame 252...
# Trying to capture frame 253...
# Trying to capture frame 254...
# Trying to capture frame 255...
# Trying to capture frame 256...
# Trying to capture frame 257...
# Trying to capture frame 258...
# Trying to capture frame 259...
# Trying to capture frame 260...
# Trying to capture frame 261...
# Trying to capture frame 262...
# Trying to capture frame 263...
# Trying to capture frame 264...
# Trying to capture frame 265...
# Trying to capture frame 266...
# Trying to capture frame 267...
# Trying to capture frame 268...
# Trying to capture frame 269...
# Captured!
# Trying to capture frame 270...
# Trying to capture frame 271...
# Trying to capture frame 272...
# Trying to capture frame 273...
# Trying to capture frame 274...
# Trying to capture frame 275...
# Trying to capture frame 276...
# Trying to capture frame 277...
# Trying to capture frame 278...
# Trying to capture frame 279...
# Trying to capture frame 280...
# Trying to capture frame 281...
# Trying to capture frame 282...
# Trying to capture frame 283...
# Trying to capture frame 284...
# Trying to capture frame 285...
# Trying to capture frame 286...
# Trying to capture frame 287...
# Trying to capture frame 288...
# Trying to capture frame 289...
# Trying to capture frame 290...
# Trying to capture frame 291...
# Trying to capture frame 292...
# Trying to capture frame 293...
# Trying to capture frame 294...
# Trying to capture frame 295...
# Trying to capture frame 296...
# Trying to capture frame 297...
# Trying to capture frame 298...
# Trying to capture frame 299...
# Trying to capture frame 300...
# Trying to capture frame 301...
# Trying to capture frame 302...
# Trying to capture frame 303...
# Trying to capture frame 304...
# Trying to capture frame 305...
# Trying to capture frame 306...
# Trying to capture frame 307...
# Trying to capture frame 308...
# Trying to capture frame 309...
# Trying to capture frame 310...
# Trying to capture frame 311...
# Trying to capture frame 312...
# Trying to capture frame 313...
# Trying to capture frame 314...
# Trying to capture frame 315...
# Trying to capture frame 316...
# Trying to capture frame 317...
# Trying to capture frame 318...
# Trying to capture frame 319...
# Captured!
# Trying to capture frame 320...
# Trying to capture frame 321...
# Trying to capture frame 322...
# Trying to capture frame 323...
# Trying to capture frame 324...
# Trying to capture frame 325...
# Trying to capture frame 326...
# Trying to capture frame 327...
# Trying to capture frame 328...
# Trying to capture frame 329...
# Trying to capture frame 330...
# Trying to capture frame 331...
# Trying to capture frame 332...
# Trying to capture frame 333...
# Trying to capture frame 334...
# Trying to capture frame 335...
# Trying to capture frame 336...
# Trying to capture frame 337...
# Trying to capture frame 338...
# Trying to capture frame 339...
# Trying to capture frame 340...
# Trying to capture frame 341...
# Trying to capture frame 342...
# Trying to capture frame 343...
# Trying to capture frame 344...
# Trying to capture frame 345...
# Trying to capture frame 346...
# Trying to capture frame 347...
# Trying to capture frame 348...
# Trying to capture frame 349...
# Trying to capture frame 350...
# Trying to capture frame 351...
# Trying to capture frame 352...
# Trying to capture frame 353...
# Trying to capture frame 354...
# Trying to capture frame 355...
# Trying to capture frame 356...
# Trying to capture frame 357...
# Trying to capture frame 358...
# Trying to capture frame 359...
# Trying to capture frame 360...
# Trying to capture frame 361...
# Trying to capture frame 362...
# Trying to capture frame 363...
# Trying to capture frame 364...
# Trying to capture frame 365...
# Trying to capture frame 366...
# Trying to capture frame 367...
# Trying to capture frame 368...
# Trying to capture frame 369...
# Trying to capture frame 370...
# Trying to capture frame 371...
# Trying to capture frame 372...
# Trying to capture frame 373...
# Trying to capture frame 374...
# Trying to capture frame 375...
# Trying to capture frame 376...
# Trying to capture frame 377...
# Trying to capture frame 378...
# Trying to capture frame 379...
# Trying to capture frame 380...
# Trying to capture frame 381...
# Trying to capture frame 382...
# Trying to capture frame 383...
# Trying to capture frame 384...
# Trying to capture frame 385...
# Trying to capture frame 386...
# Trying to capture frame 387...
# Trying to capture frame 388...
# Trying to capture frame 389...
# Trying to capture frame 390...
# Trying to capture frame 391...
# Trying to capture frame 392...
# Trying to capture frame 393...
# Trying to capture frame 394...
# Trying to capture frame 395...
# Trying to capture frame 396...
# Trying to capture frame 397...
# Trying to capture frame 398...
# Trying to capture frame 399...
# Trying to capture frame 400...
# Trying to capture frame 401...
# Trying to capture frame 402...
# Trying to capture frame 403...
# Trying to capture frame 404...
# Trying to capture frame 405...
# Trying to capture frame 406...
# Trying to capture frame 407...
# Trying to capture frame 408...
# Trying to capture frame 409...
# Trying to capture frame 410...
# Trying to capture frame 411...
# Trying to capture frame 412...
# Trying to capture frame 413...
# Trying to capture frame 414...
# Trying to capture frame 415...
# Trying to capture frame 416...
# Trying to capture frame 417...
# Trying to capture frame 418...
# Trying to capture frame 419...
# Trying to capture frame 420...
# Trying to capture frame 421...
# Trying to capture frame 422...
# Trying to capture frame 423...
# Trying to capture frame 424...
# Trying to capture frame 425...
# Trying to capture frame 426...
# Trying to capture frame 427...
# Trying to capture frame 428...
# Trying to capture frame 429...
# Trying to capture frame 430...
# Trying to capture frame 431...
# Trying to capture frame 432...
# Trying to capture frame 433...
# Captured!
# Trying to capture frame 434...
# Trying to capture frame 435...
# Trying to capture frame 436...
# Trying to capture frame 437...
# Trying to capture frame 438...
# Trying to capture frame 439...
# Trying to capture frame 440...
# Trying to capture frame 441...
# Trying to capture frame 442...
# Trying to capture frame 443...
# Trying to capture frame 444...
# Trying to capture frame 445...
# Trying to capture frame 446...
# Trying to capture frame 447...
# Trying to capture frame 448...
# Trying to capture frame 449...
# Trying to capture frame 450...
# Trying to capture frame 451...
# Trying to capture frame 452...
# Trying to capture frame 453...
# Trying to capture frame 454...
# Trying to capture frame 455...
# Trying to capture frame 456...
# Trying to capture frame 457...
# Trying to capture frame 458...
# Trying to capture frame 459...
# Trying to capture frame 460...
# Trying to capture frame 461...
# Trying to capture frame 462...
# Trying to capture frame 463...
# Trying to capture frame 464...
# Trying to capture frame 465...
# Trying to capture frame 466...
# Trying to capture frame 467...
# Trying to capture frame 468...
# Trying to capture frame 469...
# Trying to capture frame 470...
# Trying to capture frame 471...
# Trying to capture frame 472...
# Trying to capture frame 473...
# Trying to capture frame 474...
# Trying to capture frame 475...
# Trying to capture frame 476...
# Captured!
# Trying to capture frame 477...
# Trying to capture frame 478...
# Trying to capture frame 479...
# Trying to capture frame 480...
# Trying to capture frame 481...
# Trying to capture frame 482...
# Trying to capture frame 483...
# Captured!
# Trying to capture frame 484...
# Trying to capture frame 485...
# Trying to capture frame 486...
# Trying to capture frame 487...
# Trying to capture frame 488...
# Trying to capture frame 489...
# Trying to capture frame 490...
# Trying to capture frame 491...
# Captured!
# Trying to capture frame 492...
# Trying to capture frame 493...
# Trying to capture frame 494...
# Trying to capture frame 495...
# Trying to capture frame 496...
# Trying to capture frame 497...
# Trying to capture frame 498...
# Trying to capture frame 499...
# Trying to capture frame 500...
# Trying to capture frame 501...
# Trying to capture frame 502...
# Trying to capture frame 503...
# Trying to capture frame 504...
# Trying to capture frame 505...
# Trying to capture frame 506...
# Trying to capture frame 507...
# Trying to capture frame 508...
# Trying to capture frame 509...
# Trying to capture frame 510...
# Trying to capture frame 511...
# Trying to capture frame 512...
# Trying to capture frame 513...
# Trying to capture frame 514...
# Trying to capture frame 515...
# Trying to capture frame 516...
# Trying to capture frame 517...
# Trying to capture frame 518...
# Trying to capture frame 519...
# Trying to capture frame 520...
# Trying to capture frame 521...
# Trying to capture frame 522...
# Trying to capture frame 523...
# Trying to capture frame 524...
# Trying to capture frame 525...
# Trying to capture frame 526...
# Trying to capture frame 527...
# Trying to capture frame 528...
# Trying to capture frame 529...
# Trying to capture frame 530...
# Trying to capture frame 531...
# Trying to capture frame 532...
# Trying to capture frame 533...
# Trying to capture frame 534...
# Trying to capture frame 535...
# Trying to capture frame 536...
# Trying to capture frame 537...
# Trying to capture frame 538...
# Trying to capture frame 539...
# Trying to capture frame 540...
# Trying to capture frame 541...
# Trying to capture frame 542...
# Trying to capture frame 543...
# Trying to capture frame 544...
# Trying to capture frame 545...
# Trying to capture frame 546...
# Trying to capture frame 547...
# Trying to capture frame 548...
# Trying to capture frame 549...
# Trying to capture frame 550...
# Trying to capture frame 551...
# Trying to capture frame 552...
# Trying to capture frame 553...
# Trying to capture frame 554...
# Trying to capture frame 555...
# Trying to capture frame 556...
# Trying to capture frame 557...
# Captured!
# Trying to capture frame 558...
# Trying to capture frame 559...
# Captured!
# Trying to capture frame 560...
# Trying to capture frame 561...
# Trying to capture frame 562...
# Trying to capture frame 563...
# Trying to capture frame 564...
# Trying to capture frame 565...
# Trying to capture frame 566...
# Trying to capture frame 567...
# Captured!
# Trying to capture frame 568...
# Trying to capture frame 569...
# Trying to capture frame 570...
# Trying to capture frame 571...
# Trying to capture frame 572...
# Trying to capture frame 573...
# Trying to capture frame 574...
# Captured!
# Trying to capture frame 575...
# Captured!
# Trying to capture frame 576...
# Captured!
# Trying to capture frame 577...
# Captured!
# Trying to capture frame 578...
# Captured!
# Trying to capture frame 579...
# Captured!
# Trying to capture frame 580...
# Trying to capture frame 581...
# Trying to capture frame 582...
# Trying to capture frame 583...
# Trying to capture frame 584...
# Trying to capture frame 585...
# Trying to capture frame 586...
# Trying to capture frame 587...
# Trying to capture frame 588...
# Trying to capture frame 589...
# Captured!
# Trying to capture frame 590...
# Captured!
# Trying to capture frame 591...
# Trying to capture frame 592...
# Trying to capture frame 593...
# Captured!
# Trying to capture frame 594...
# Trying to capture frame 595...
# Trying to capture frame 596...
# Trying to capture frame 597...
# Trying to capture frame 598...
# Trying to capture frame 599...
# Trying to capture frame 600...
# Trying to capture frame 601...
# Trying to capture frame 602...
# Trying to capture frame 603...
# Trying to capture frame 604...
# Trying to capture frame 605...
# Trying to capture frame 606...
# Trying to capture frame 607...
# Trying to capture frame 608...
# Trying to capture frame 609...
# Trying to capture frame 610...
# Trying to capture frame 611...
# Trying to capture frame 612...
# Trying to capture frame 613...
# Trying to capture frame 614...
# Trying to capture frame 615...
# Trying to capture frame 616...
# Trying to capture frame 617...
# Trying to capture frame 618...
# Trying to capture frame 619...
# Trying to capture frame 620...
# Trying to capture frame 621...
# Trying to capture frame 622...
# Trying to capture frame 623...
# Trying to capture frame 624...
# Trying to capture frame 625...
# Trying to capture frame 626...
# Trying to capture frame 627...
# Trying to capture frame 628...
# Trying to capture frame 629...
# Trying to capture frame 630...
# Trying to capture frame 631...
# Trying to capture frame 632...
# Trying to capture frame 633...
# Trying to capture frame 634...
# Trying to capture frame 635...
# Trying to capture frame 636...
# Trying to capture frame 637...
# Trying to capture frame 638...
# Trying to capture frame 639...
# Trying to capture frame 640...
# Trying to capture frame 641...
# Trying to capture frame 642...
# Trying to capture frame 643...
# Trying to capture frame 644...
# Trying to capture frame 645...
# Trying to capture frame 646...
# Trying to capture frame 647...
# Trying to capture frame 648...
# Trying to capture frame 649...
# Trying to capture frame 650...
# Trying to capture frame 651...
# Trying to capture frame 652...
# Trying to capture frame 653...
# Trying to capture frame 654...
# Trying to capture frame 655...
# Trying to capture frame 656...
# Trying to capture frame 657...
# Trying to capture frame 658...
# Trying to capture frame 659...
# Trying to capture frame 660...
# Trying to capture frame 661...
# Trying to capture frame 662...
# Trying to capture frame 663...
# Trying to capture frame 664...
# Trying to capture frame 665...
# Trying to capture frame 666...
# Trying to capture frame 667...
# Trying to capture frame 668...
# Trying to capture frame 669...
# Trying to capture frame 670...
# Trying to capture frame 671...
# Trying to capture frame 672...
# Trying to capture frame 673...
# Trying to capture frame 674...
# Trying to capture frame 675...
# Trying to capture frame 676...
# Trying to capture frame 677...
# Trying to capture frame 678...
# Trying to capture frame 679...
# Trying to capture frame 680...
# Trying to capture frame 681...
# Trying to capture frame 682...
# Trying to capture frame 683...
# Trying to capture frame 684...
# Trying to capture frame 685...
# Trying to capture frame 686...
# Trying to capture frame 687...
# Trying to capture frame 688...
# Trying to capture frame 689...
# Captured!
# Trying to capture frame 690...
# Captured!
# Trying to capture frame 691...
# Captured!
# Trying to capture frame 692...
# Trying to capture frame 693...
# Trying to capture frame 694...
# Trying to capture frame 695...
# Trying to capture frame 696...
# Trying to capture frame 697...
# Trying to capture frame 698...
# Captured!
# Trying to capture frame 699...
# Trying to capture frame 700...
# Trying to capture frame 701...
# Trying to capture frame 702...
# Captured!
# Trying to capture frame 703...
# Trying to capture frame 704...
# Trying to capture frame 705...
# Trying to capture frame 706...
# Trying to capture frame 707...
# Trying to capture frame 708...
# Trying to capture frame 709...
# Captured!
# Trying to capture frame 710...
# Captured!
# Trying to capture frame 711...
# Captured!
# Trying to capture frame 712...
# Captured!
# Trying to capture frame 713...
# Trying to capture frame 714...
# Trying to capture frame 715...
# Trying to capture frame 716...
# Trying to capture frame 717...
# Trying to capture frame 718...
# Trying to capture frame 719...
# Trying to capture frame 720...
# Trying to capture frame 721...
# Trying to capture frame 722...
# Trying to capture frame 723...
# Trying to capture frame 724...
# Trying to capture frame 725...
# Trying to capture frame 726...
# Trying to capture frame 727...
# Trying to capture frame 728...
# Trying to capture frame 729...
# Trying to capture frame 730...
# Trying to capture frame 731...
# Trying to capture frame 732...
# Trying to capture frame 733...
# Trying to capture frame 734...
# Trying to capture frame 735...
# Trying to capture frame 736...
# Trying to capture frame 737...
# Trying to capture frame 738...
# Trying to capture frame 739...
# Trying to capture frame 740...
# Trying to capture frame 741...
# Trying to capture frame 742...
# Trying to capture frame 743...
# Trying to capture frame 744...
# Trying to capture frame 745...
# Trying to capture frame 746...
# Trying to capture frame 747...
# Trying to capture frame 748...
# Captured!
# Trying to capture frame 749...
# Captured!
# Trying to capture frame 750...
# Captured!
# Trying to capture frame 751...
# Captured!
# Trying to capture frame 752...
# Trying to capture frame 753...
# Captured!
# Trying to capture frame 754...
# Trying to capture frame 755...
# Trying to capture frame 756...
# Captured!
# Trying to capture frame 757...
# Captured!
# Trying to capture frame 758...
# Trying to capture frame 759...
# Trying to capture frame 760...
# Trying to capture frame 761...
# Trying to capture frame 762...
# Trying to capture frame 763...
# Trying to capture frame 764...
# Trying to capture frame 765...
# Trying to capture frame 766...
# Trying to capture frame 767...
# Trying to capture frame 768...
# Captured!
# Trying to capture frame 769...
# Captured!
# Trying to capture frame 770...
# Captured!
# Trying to capture frame 771...
# Trying to capture frame 772...
# Captured!
# Trying to capture frame 773...
# Captured!
# Trying to capture frame 774...
# Captured!
# Trying to capture frame 775...
# Captured!
# Trying to capture frame 776...
# Captured!
# Trying to capture frame 777...
# Captured!
# Trying to capture frame 778...
# Captured!
# Trying to capture frame 779...
# Captured!
# Trying to capture frame 780...
# Captured!
# Trying to capture frame 781...
# Captured!
# Trying to capture frame 782...
# Trying to capture frame 783...
# Trying to capture frame 784...
# Trying to capture frame 785...
# Trying to capture frame 786...
# Trying to capture frame 787...
# Trying to capture frame 788...
# Trying to capture frame 789...
# Trying to capture frame 790...
# Trying to capture frame 791...
# Trying to capture frame 792...
# Trying to capture frame 793...
# Trying to capture frame 794...
# Trying to capture frame 795...
# Trying to capture frame 796...
# Trying to capture frame 797...
# Trying to capture frame 798...
# Trying to capture frame 799...
# Trying to capture frame 800...
# Trying to capture frame 801...
# Trying to capture frame 802...
# Trying to capture frame 803...
# Trying to capture frame 804...
# Trying to capture frame 805...
# Trying to capture frame 806...
# Trying to capture frame 807...
# Captured!
# Trying to capture frame 808...
# Trying to capture frame 809...
# Trying to capture frame 810...
# Trying to capture frame 811...
# Trying to capture frame 812...
# Trying to capture frame 813...
# Trying to capture frame 814...
# Trying to capture frame 815...
# Trying to capture frame 816...
# Trying to capture frame 817...
# Trying to capture frame 818...
# Trying to capture frame 819...
# Trying to capture frame 820...
# Trying to capture frame 821...
# Trying to capture frame 822...
# Trying to capture frame 823...
# Trying to capture frame 824...
# Trying to capture frame 825...
# Trying to capture frame 826...
# Trying to capture frame 827...
# Trying to capture frame 828...
# Trying to capture frame 829...
# Trying to capture frame 830...
# Trying to capture frame 831...
# Trying to capture frame 832...
# Trying to capture frame 833...
# Trying to capture frame 834...
# Trying to capture frame 835...
# Trying to capture frame 836...
# Trying to capture frame 837...
# Trying to capture frame 838...
# Trying to capture frame 839...
# Trying to capture frame 840...
# Trying to capture frame 841...
# Captured!
# Trying to capture frame 842...
# Trying to capture frame 843...
# Trying to capture frame 844...
# Trying to capture frame 845...
# Trying to capture frame 846...
# Trying to capture frame 847...
# Trying to capture frame 848...
# Trying to capture frame 849...
# Trying to capture frame 850...
# Trying to capture frame 851...
# Trying to capture frame 852...
# Trying to capture frame 853...
# Trying to capture frame 854...
# Trying to capture frame 855...
# Trying to capture frame 856...
# Trying to capture frame 857...
# Trying to capture frame 858...
# Trying to capture frame 859...
# Trying to capture frame 860...
# Trying to capture frame 861...
# Trying to capture frame 862...
# Trying to capture frame 863...
# Trying to capture frame 864...
# Trying to capture frame 865...
# Trying to capture frame 866...
# Trying to capture frame 867...
# Trying to capture frame 868...
# Trying to capture frame 869...
# Trying to capture frame 870...
# Trying to capture frame 871...
# Trying to capture frame 872...
# Trying to capture frame 873...
# Trying to capture frame 874...
# Trying to capture frame 875...
# Trying to capture frame 876...
# Trying to capture frame 877...
# Trying to capture frame 878...
# Trying to capture frame 879...
# Trying to capture frame 880...
# Trying to capture frame 881...
# Trying to capture frame 882...
# Trying to capture frame 883...
# Trying to capture frame 884...
# Trying to capture frame 885...
# Trying to capture frame 886...
# Trying to capture frame 887...
# Trying to capture frame 888...
# Trying to capture frame 889...
# Trying to capture frame 890...
# Trying to capture frame 891...
# Trying to capture frame 892...
# Trying to capture frame 893...
# Trying to capture frame 894...
# Trying to capture frame 895...
# Trying to capture frame 896...
# Trying to capture frame 897...
# Trying to capture frame 898...
# Trying to capture frame 899...
# Trying to capture frame 900...
# Trying to capture frame 901...
# Trying to capture frame 902...
# Trying to capture frame 903...
# Trying to capture frame 904...
# Trying to capture frame 905...
# Trying to capture frame 906...
# Trying to capture frame 907...
# Trying to capture frame 908...
# Trying to capture frame 909...
# Trying to capture frame 910...
# Trying to capture frame 911...
# Captured!
# Trying to capture frame 912...
# Captured!
# Trying to capture frame 913...
# Captured!
# Trying to capture frame 914...
# Captured!
# Trying to capture frame 915...
# Captured!
# Trying to capture frame 916...
# Captured!
# Trying to capture frame 917...
# Captured!
# Trying to capture frame 918...
# Captured!
# Trying to capture frame 919...
# Captured!
# Trying to capture frame 920...
# Captured!
# Trying to capture frame 921...
# Captured!
# Trying to capture frame 922...
# Captured!
# Trying to capture frame 923...
# Captured!
# Trying to capture frame 924...
# Captured!
# Trying to capture frame 925...
# Captured!
# Trying to capture frame 926...
# Captured!
# Trying to capture frame 927...
# Captured!
# Trying to capture frame 928...
# Captured!
# Trying to capture frame 929...
# Captured!
# Trying to capture frame 930...
# Captured!
# Trying to capture frame 931...
# Trying to capture frame 932...
# Captured!
# Trying to capture frame 933...
# Trying to capture frame 934...
# Trying to capture frame 935...
# Trying to capture frame 936...
# Captured!
# Trying to capture frame 937...
# Captured!
# Trying to capture frame 938...
# Trying to capture frame 939...
# Trying to capture frame 940...
# Trying to capture frame 941...
# Trying to capture frame 942...
# Trying to capture frame 943...
# Trying to capture frame 944...
# Trying to capture frame 945...
# Trying to capture frame 946...
# Trying to capture frame 947...
# Trying to capture frame 948...
# Trying to capture frame 949...
# Trying to capture frame 950...
# Trying to capture frame 951...
# Trying to capture frame 952...
# Trying to capture frame 953...
# Trying to capture frame 954...
# Trying to capture frame 955...
# Captured!
# Trying to capture frame 956...
# Trying to capture frame 957...
# Trying to capture frame 958...
# Trying to capture frame 959...
# Trying to capture frame 960...
# Trying to capture frame 961...
# Trying to capture frame 962...
# Trying to capture frame 963...
# Trying to capture frame 964...
# Trying to capture frame 965...
# Trying to capture frame 966...
# Trying to capture frame 967...
# Trying to capture frame 968...
# Captured!
# Trying to capture frame 969...
# Captured!
# Trying to capture frame 970...
# Trying to capture frame 971...
# Trying to capture frame 972...
# Trying to capture frame 973...
# Trying to capture frame 974...
# Trying to capture frame 975...
# Trying to capture frame 976...
# Trying to capture frame 977...
# Trying to capture frame 978...
# Trying to capture frame 979...
# Trying to capture frame 980...
# Trying to capture frame 981...
# Trying to capture frame 982...
# Trying to capture frame 983...
# Trying to capture frame 984...
# Trying to capture frame 985...
# Trying to capture frame 986...
# Trying to capture frame 987...
# Trying to capture frame 988...
# Trying to capture frame 989...
# Trying to capture frame 990...
# Trying to capture frame 991...
# Trying to capture frame 992...
# Trying to capture frame 993...
# Trying to capture frame 994...
# Captured!
# Trying to capture frame 995...
# Captured!
# Trying to capture frame 996...
# Captured!
# Trying to capture frame 997...
# Trying to capture frame 998...
# Trying to capture frame 999...
# Trying to capture frame 1000...
# Trying to capture frame 1001...
# Trying to capture frame 1002...
# Trying to capture frame 1003...
# Trying to capture frame 1004...
# Trying to capture frame 1005...
# Trying to capture frame 1006...
# Trying to capture frame 1007...
# Trying to capture frame 1008...
# Trying to capture frame 1009...
# Trying to capture frame 1010...
# Trying to capture frame 1011...
# Trying to capture frame 1012...
# Trying to capture frame 1013...
# Trying to capture frame 1014...
# Trying to capture frame 1015...
# Trying to capture frame 1016...
# Trying to capture frame 1017...
# Trying to capture frame 1018...
# Trying to capture frame 1019...
# Trying to capture frame 1020...
# Trying to capture frame 1021...
# Trying to capture frame 1022...
# Captured!
# Trying to capture frame 1023...
# Trying to capture frame 1024...
# Trying to capture frame 1025...
# Captured!
# Trying to capture frame 1026...
# Captured!
# Trying to capture frame 1027...
# Trying to capture frame 1028...
# Trying to capture frame 1029...
# Trying to capture frame 1030...
# Trying to capture frame 1031...
# Trying to capture frame 1032...
# Trying to capture frame 1033...
# Trying to capture frame 1034...
# Trying to capture frame 1035...
# Captured!
# Trying to capture frame 1036...
# Captured!
# Trying to capture frame 1037...
# Captured!
# Trying to capture frame 1038...
# Captured!
# Trying to capture frame 1039...
# Captured!
# Trying to capture frame 1040...
# Captured!
# Trying to capture frame 1041...
# Trying to capture frame 1042...
# Captured!
# Trying to capture frame 1043...
# Captured!
# Trying to capture frame 1044...
# Trying to capture frame 1045...
# Trying to capture frame 1046...
# Trying to capture frame 1047...
# Trying to capture frame 1048...
# Trying to capture frame 1049...
# Trying to capture frame 1050...
# Trying to capture frame 1051...
# Trying to capture frame 1052...
# Trying to capture frame 1053...
# Trying to capture frame 1054...
# Trying to capture frame 1055...
# Trying to capture frame 1056...
# Trying to capture frame 1057...
# Trying to capture frame 1058...
# Trying to capture frame 1059...
# Trying to capture frame 1060...
# Trying to capture frame 1061...
# Trying to capture frame 1062...
# Trying to capture frame 1063...
# Trying to capture frame 1064...
# Trying to capture frame 1065...
# Trying to capture frame 1066...
# Trying to capture frame 1067...
# Trying to capture frame 1068...
# Trying to capture frame 1069...
# Trying to capture frame 1070...
# Trying to capture frame 1071...
# Trying to capture frame 1072...
# Trying to capture frame 1073...
# Trying to capture frame 1074...
# Trying to capture frame 1075...
# Trying to capture frame 1076...
# Trying to capture frame 1077...
# Trying to capture frame 1078...
# Trying to capture frame 1079...
# Trying to capture frame 1080...
# Trying to capture frame 1081...
# Trying to capture frame 1082...
# Trying to capture frame 1083...
# Trying to capture frame 1084...
# Trying to capture frame 1085...
# Trying to capture frame 1086...
# Trying to capture frame 1087...
# Trying to capture frame 1088...
# Trying to capture frame 1089...
# Trying to capture frame 1090...
# Trying to capture frame 1091...
# Trying to capture frame 1092...
# Trying to capture frame 1093...
# Trying to capture frame 1094...
# Trying to capture frame 1095...
# Trying to capture frame 1096...
# Trying to capture frame 1097...
# Trying to capture frame 1098...
# Trying to capture frame 1099...
# Trying to capture frame 1100...
# Trying to capture frame 1101...
# Trying to capture frame 1102...
# Trying to capture frame 1103...
# Trying to capture frame 1104...
# Trying to capture frame 1105...
# Trying to capture frame 1106...
# Trying to capture frame 1107...
# Trying to capture frame 1108...
# Trying to capture frame 1109...
# Trying to capture frame 1110...
# Trying to capture frame 1111...
# Trying to capture frame 1112...
# Trying to capture frame 1113...
# Trying to capture frame 1114...
# Trying to capture frame 1115...
# Trying to capture frame 1116...
# Trying to capture frame 1117...
# Trying to capture frame 1118...
# Trying to capture frame 1119...
# Trying to capture frame 1120...
# Trying to capture frame 1121...
# Trying to capture frame 1122...
# Trying to capture frame 1123...
# Trying to capture frame 1124...
# Trying to capture frame 1125...
# Trying to capture frame 1126...
# Trying to capture frame 1127...
# Trying to capture frame 1128...
# Trying to capture frame 1129...
# Trying to capture frame 1130...
# Trying to capture frame 1131...
# Trying to capture frame 1132...
# Trying to capture frame 1133...
# Trying to capture frame 1134...
# Trying to capture frame 1135...
# Trying to capture frame 1136...
# Trying to capture frame 1137...
# Trying to capture frame 1138...
# Trying to capture frame 1139...
# Trying to capture frame 1140...
# Trying to capture frame 1141...
# Trying to capture frame 1142...
# Trying to capture frame 1143...
# Trying to capture frame 1144...
# Trying to capture frame 1145...
# Trying to capture frame 1146...
# Trying to capture frame 1147...
# Trying to capture frame 1148...
# Trying to capture frame 1149...
# Trying to capture frame 1150...
# Trying to capture frame 1151...
# Trying to capture frame 1152...
# Trying to capture frame 1153...
# Trying to capture frame 1154...
# Trying to capture frame 1155...
# Trying to capture frame 1156...
# Trying to capture frame 1157...
# Trying to capture frame 1158...
# Trying to capture frame 1159...
# Trying to capture frame 1160...
# Trying to capture frame 1161...
# Trying to capture frame 1162...
# Trying to capture frame 1163...
# Trying to capture frame 1164...
# Trying to capture frame 1165...
# Trying to capture frame 1166...
# Trying to capture frame 1167...
# Trying to capture frame 1168...
# Trying to capture frame 1169...
# Trying to capture frame 1170...
# Trying to capture frame 1171...
# Trying to capture frame 1172...
# Trying to capture frame 1173...
# Trying to capture frame 1174...
# Trying to capture frame 1175...
# Trying to capture frame 1176...
# Trying to capture frame 1177...
# Trying to capture frame 1178...
# Trying to capture frame 1179...
# Trying to capture frame 1180...
# Trying to capture frame 1181...
# Trying to capture frame 1182...
# Trying to capture frame 1183...
# Trying to capture frame 1184...
# Trying to capture frame 1185...
# Trying to capture frame 1186...
# Trying to capture frame 1187...
# Trying to capture frame 1188...
# Trying to capture frame 1189...
# Trying to capture frame 1190...
# Trying to capture frame 1191...
# Trying to capture frame 1192...
# Trying to capture frame 1193...
# Trying to capture frame 1194...
# Trying to capture frame 1195...
# Trying to capture frame 1196...
# Trying to capture frame 1197...
# Trying to capture frame 1198...
# Trying to capture frame 1199...
# Trying to capture frame 1200...
# Trying to capture frame 1201...
# Trying to capture frame 1202...
# Trying to capture frame 1203...
# Trying to capture frame 1204...
# Trying to capture frame 1205...
# Trying to capture frame 1206...
# Trying to capture frame 1207...
# Trying to capture frame 1208...
# Trying to capture frame 1209...
# Trying to capture frame 1210...
# Trying to capture frame 1211...
# Trying to capture frame 1212...
# Trying to capture frame 1213...
# Trying to capture frame 1214...
# Trying to capture frame 1215...
# Trying to capture frame 1216...
# Trying to capture frame 1217...
# Trying to capture frame 1218...
# Trying to capture frame 1219...
# Trying to capture frame 1220...
# Trying to capture frame 1221...
# Trying to capture frame 1222...
# Trying to capture frame 1223...
# Trying to capture frame 1224...
# Trying to capture frame 1225...
# Trying to capture frame 1226...
# Trying to capture frame 1227...
# Trying to capture frame 1228...
# Trying to capture frame 1229...
# Trying to capture frame 1230...
# Trying to capture frame 1231...
# Trying to capture frame 1232...
# Trying to capture frame 1233...
# Trying to capture frame 1234...
# Trying to capture frame 1235...
# Trying to capture frame 1236...
# Trying to capture frame 1237...
# Trying to capture frame 1238...
# Trying to capture frame 1239...
# Trying to capture frame 1240...
# Trying to capture frame 1241...
# Trying to capture frame 1242...
# Trying to capture frame 1243...
# Trying to capture frame 1244...
# Trying to capture frame 1245...
# Trying to capture frame 1246...
# Trying to capture frame 1247...
# Trying to capture frame 1248...
# Trying to capture frame 1249...
# Trying to capture frame 1250...
# Trying to capture frame 1251...
# Trying to capture frame 1252...
# Trying to capture frame 1253...
# Trying to capture frame 1254...
# Trying to capture frame 1255...
# Trying to capture frame 1256...
# Captured!
# Trying to capture frame 1257...
# Trying to capture frame 1258...
# Trying to capture frame 1259...
# Trying to capture frame 1260...
# Trying to capture frame 1261...
# Trying to capture frame 1262...
# Trying to capture frame 1263...
# Trying to capture frame 1264...
# Trying to capture frame 1265...
# Trying to capture frame 1266...
# Trying to capture frame 1267...
# Trying to capture frame 1268...
# Trying to capture frame 1269...
# Trying to capture frame 1270...
# Trying to capture frame 1271...
# Trying to capture frame 1272...
# Trying to capture frame 1273...
# Trying to capture frame 1274...
# Trying to capture frame 1275...
# Trying to capture frame 1276...
# Trying to capture frame 1277...
# Trying to capture frame 1278...
# Trying to capture frame 1279...
# Captured!
# Trying to capture frame 1280...
# Trying to capture frame 1281...
# Trying to capture frame 1282...
# Trying to capture frame 1283...
# Trying to capture frame 1284...
# Trying to capture frame 1285...
# Captured!
# Trying to capture frame 1286...
# Captured!
# Trying to capture frame 1287...
# Captured!
# Trying to capture frame 1288...
# Captured!
# Trying to capture frame 1289...
# Captured!
# Trying to capture frame 1290...
# Captured!
# Trying to capture frame 1291...
# Captured!
# Trying to capture frame 1292...
# Trying to capture frame 1293...
# Trying to capture frame 1294...
# Trying to capture frame 1295...
# Trying to capture frame 1296...
# Trying to capture frame 1297...
# Trying to capture frame 1298...
# Trying to capture frame 1299...
# Trying to capture frame 1300...
# Trying to capture frame 1301...
# Trying to capture frame 1302...
# Trying to capture frame 1303...
# Trying to capture frame 1304...
# Trying to capture frame 1305...
# Trying to capture frame 1306...
# Trying to capture frame 1307...
# Trying to capture frame 1308...
# Trying to capture frame 1309...
# Trying to capture frame 1310...
# Trying to capture frame 1311...
# Trying to capture frame 1312...
# Captured!
# Trying to capture frame 1313...
# Captured!
# Trying to capture frame 1314...
# Trying to capture frame 1315...
# Trying to capture frame 1316...
# Trying to capture frame 1317...
# Trying to capture frame 1318...
# Trying to capture frame 1319...
# Trying to capture frame 1320...
# Trying to capture frame 1321...
# Trying to capture frame 1322...
# Trying to capture frame 1323...
# Trying to capture frame 1324...
# Trying to capture frame 1325...
# Trying to capture frame 1326...
# Trying to capture frame 1327...
# Trying to capture frame 1328...
# Trying to capture frame 1329...
# Trying to capture frame 1330...
# Trying to capture frame 1331...
# Trying to capture frame 1332...
# Trying to capture frame 1333...
# Trying to capture frame 1334...
# Trying to capture frame 1335...
# Trying to capture frame 1336...
# Trying to capture frame 1337...
# Trying to capture frame 1338...
# Trying to capture frame 1339...
# Trying to capture frame 1340...
# Captured!
# Trying to capture frame 1341...
# Captured!
# Trying to capture frame 1342...
# Captured!
# Trying to capture frame 1343...
# Trying to capture frame 1344...
# Captured!
# Trying to capture frame 1345...
# Trying to capture frame 1346...
# Trying to capture frame 1347...
# Trying to capture frame 1348...
# Trying to capture frame 1349...
# Captured!
# Trying to capture frame 1350...
# Captured!
# Trying to capture frame 1351...
# Trying to capture frame 1352...
# Trying to capture frame 1353...
# Trying to capture frame 1354...
# Trying to capture frame 1355...
# Trying to capture frame 1356...
# Trying to capture frame 1357...
# Trying to capture frame 1358...
# Trying to capture frame 1359...
# Trying to capture frame 1360...
# Trying to capture frame 1361...
# Trying to capture frame 1362...
# Trying to capture frame 1363...
# Trying to capture frame 1364...
# Trying to capture frame 1365...
# Trying to capture frame 1366...
# Trying to capture frame 1367...
# Trying to capture frame 1368...
# Trying to capture frame 1369...
# Trying to capture frame 1370...
# Trying to capture frame 1371...
# Trying to capture frame 1372...
# Trying to capture frame 1373...
# Trying to capture frame 1374...
# Trying to capture frame 1375...
# Trying to capture frame 1376...
# Trying to capture frame 1377...
# Trying to capture frame 1378...
# Trying to capture frame 1379...
# Trying to capture frame 1380...
# Trying to capture frame 1381...
# Trying to capture frame 1382...
# Trying to capture frame 1383...
# Trying to capture frame 1384...
# Trying to capture frame 1385...
# Trying to capture frame 1386...
# Trying to capture frame 1387...
# Trying to capture frame 1388...
# Trying to capture frame 1389...
# Trying to capture frame 1390...
# Trying to capture frame 1391...
# Trying to capture frame 1392...
# Trying to capture frame 1393...
# Trying to capture frame 1394...
# Trying to capture frame 1395...
# Trying to capture frame 1396...
# Trying to capture frame 1397...
# Trying to capture frame 1398...
# Trying to capture frame 1399...
# Trying to capture frame 1400...
# Trying to capture frame 1401...
# Trying to capture frame 1402...
# Trying to capture frame 1403...
# Trying to capture frame 1404...
# Trying to capture frame 1405...
# Trying to capture frame 1406...
# Trying to capture frame 1407...
# Trying to capture frame 1408...
# Trying to capture frame 1409...
# Trying to capture frame 1410...
# Trying to capture frame 1411...
# Trying to capture frame 1412...
# Trying to capture frame 1413...
# Trying to capture frame 1414...
# Trying to capture frame 1415...
# Trying to capture frame 1416...
# Trying to capture frame 1417...
# Trying to capture frame 1418...
# Trying to capture frame 1419...
# Trying to capture frame 1420...
# Trying to capture frame 1421...
# Trying to capture frame 1422...
# Trying to capture frame 1423...
# Trying to capture frame 1424...
# Trying to capture frame 1425...
# Trying to capture frame 1426...
# Trying to capture frame 1427...
# Trying to capture frame 1428...
# Trying to capture frame 1429...
# Trying to capture frame 1430...
# Trying to capture frame 1431...
# Trying to capture frame 1432...
# Trying to capture frame 1433...
# Trying to capture frame 1434...
# Trying to capture frame 1435...
# Trying to capture frame 1436...
# Trying to capture frame 1437...
# Trying to capture frame 1438...
# Trying to capture frame 1439...
# Trying to capture frame 1440...
# Trying to capture frame 1441...
# Trying to capture frame 1442...
# Trying to capture frame 1443...
# Trying to capture frame 1444...
# Trying to capture frame 1445...
# Trying to capture frame 1446...
# Trying to capture frame 1447...
# Trying to capture frame 1448...
# Trying to capture frame 1449...
# Trying to capture frame 1450...
# Trying to capture frame 1451...
# Trying to capture frame 1452...
# Trying to capture frame 1453...
# Trying to capture frame 1454...
# Trying to capture frame 1455...
# Trying to capture frame 1456...
# Trying to capture frame 1457...
# Trying to capture frame 1458...
# Trying to capture frame 1459...
# Trying to capture frame 1460...
# Trying to capture frame 1461...
# Trying to capture frame 1462...
# Trying to capture frame 1463...
# Trying to capture frame 1464...
# Trying to capture frame 1465...
# Trying to capture frame 1466...
# Trying to capture frame 1467...
# Trying to capture frame 1468...
# Trying to capture frame 1469...
# Trying to capture frame 1470...
# Trying to capture frame 1471...
# Trying to capture frame 1472...
# Trying to capture frame 1473...
# Trying to capture frame 1474...
# Trying to capture frame 1475...
# Trying to capture frame 1476...
# Trying to capture frame 1477...
# Trying to capture frame 1478...
# Trying to capture frame 1479...
# Trying to capture frame 1480...
# Trying to capture frame 1481...
# Trying to capture frame 1482...
# Trying to capture frame 1483...
# Trying to capture frame 1484...
# Trying to capture frame 1485...
# Trying to capture frame 1486...
# Trying to capture frame 1487...
# Trying to capture frame 1488...
# Trying to capture frame 1489...
# Trying to capture frame 1490...
# Trying to capture frame 1491...
# Trying to capture frame 1492...
# Trying to capture frame 1493...
# Trying to capture frame 1494...
# Trying to capture frame 1495...
# Trying to capture frame 1496...
# Total frame count: 1496
# 33 frame of landmarks captured
# Total frame count: 1496
# 33 frame of landmarks captured
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
def predict(path):
  audio_path = get_audio_path(path)
  #audio_prediction_vectors, audio_prediction_labels = audio_predict(audio_path)
  #visual_prediction_vectors, visual_prediction_labels = visual_predict(path)

  print(f"audio_prediction {audio_prediction_labels}")
  print(f"visual_prediction {visual_prediction_labels}")
  print(f"Length check: audio {len(audio_prediction_labels)}, visual: {len(visual_prediction_labels)}")

  combined_labels = []
  for i in range(len(visual_prediction_vectors)):
    audio_prediction_vector = list(audio_prediction_vectors[i])
    visual_prediction_vector = list(visual_prediction_vectors[i][0])

    # calcuate combine vector for each interval
    combined_vector = []
    for j in range(8):
      combined_vector.append(audio_prediction_vector[j] + 3*visual_prediction_vector[j])

    max_index = np.argmax(combined_vector)
    combined_labels.append(predictions_dict[max_index])

  print(f"Combined labels: {combined_labels}")
  return audio_prediction_labels,visual_prediction_labels, combined_labels

# %%
audio_prediction_labels,visual_prediction_labels, combined_labels = predict(demo_path)
# Out:
# audio_prediction ['sad', 'sad', 'calm', 'calm', 'disgust', 'calm', 'disgust', 'calm', 'calm', 'sad', 'disgust', 'disgust', 'calm', 'disgust', 'angry', 'sad', 'calm', 'disgust', 'calm', 'disgust', 'disgust', 'disgust', 'sad', 'calm', 'calm', 'calm', 'disgust', 'calm', 'calm', 'calm', 'happy', 'happy', 'happy']
# visual_prediction ['surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'disgust', 'disgust', 'disgust', 'fear', 'surprise', 'surprise', 'surprise', 'surprise', 'sad', 'happy', 'happy', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'sad', 'surprise', 'surprise', 'surprise', 'surprise']
# Length check: audio 33, visual: 33
# Combined labels: ['surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'disgust', 'disgust', 'disgust', 'fear', 'surprise', 'surprise', 'surprise', 'surprise', 'sad', 'happy', 'happy', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'surprise', 'sad', 'surprise', 'surprise', 'surprise', 'surprise']

# %% [markdown]
# ###Display emotion prediction result
# Using our own demo video, we can display the prediction from audio and visual predictions, as well as the combined prediction, along with the demo video using OpenCV.
#
# Note: we already have `audio_prediction_labels`, `visual_prediction_labels`, `combined_labels` computed from previous parts.

# %%
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture(demo_path)

frame_count = 0
while(True):
    frame_count += 1
    # Capture frames in the video
    ret, frame = cap.read()

    # describe the type of font
    # to be used.
    font = cv2.FONT_HERSHEY_SIMPLEX

    interval_count = frame_count // 45
    text = "Visual: " + visual_prediction_labels[interval_count] + \
           "\nAudio: " + audio_prediction_labels[interval_count] + \
           "\nCombined " + combined_labels[interval_count]

    # Use putText() method for
    # inserting text on video
    cv2.putText(frame,
                text,
                (50, 50),
                font, 1,
                (0, 255, 255),
                2,
                cv2.LINE_4)

    # Display the resulting frame
    cv2_imshow(frame, reverse=True)

    # creating 'q' as the quit
    # button for the video
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# release the cap object
cap.release()
# close all windows
cv2.destroyAllWindows()

# %% [markdown]
# ###Music generation

# %% [markdown]
# ####Import libraries and helpers

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !apt-get update -qq && apt-get install -qq libfluidsynth1 fluid-soundfont-gm build-essential libasound2-dev libjack-dev
# Out:
# Selecting previously unselected package fluid-soundfont-gm.
# (Reading database ... 124013 files and directories currently installed.)
# Preparing to unpack .../fluid-soundfont-gm_3.1-5.1_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.1) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up fluid-soundfont-gm (3.1-5.1) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...

# %%
# !pip install -qU pyfluidsynth pretty_midi
# Out:
#      |████████████████████████████████| 5.6 MB 13.7 MB/s
#      |████████████████████████████████| 51 kB 7.7 MB/s
#   Building wheel for pretty-midi (setup.py) ... done

# %%
import collections
import datetime
import fluidsynth
from fluidsynth import *
import glob
import numpy as np
import pathlib
import pandas as pd
import pretty_midi
import seaborn as sns
import tensorflow as tf
from google.colab import files
import random
from IPython import display
from matplotlib import pyplot as plt
from typing import Dict, List, Optional, Sequence, Tuple

# %%
def midi_to_notes(midi_file: str):
  pm = pretty_midi.PrettyMIDI(midi_file)
  instrument = pm.instruments[0]
  instrument_name = pretty_midi.program_to_instrument_name(instrument.program)
  notes = collections.defaultdict(list)

  # Sort the notes by start time
  sorted_notes = sorted(instrument.notes, key=lambda note: note.start)
  prev_start = sorted_notes[0].start

  for note in sorted_notes:
    start = note.start
    end = note.end
    notes['pitch'].append(note.pitch)
    notes['start'].append(start)
    notes['end'].append(end)
    notes['step'].append(start - prev_start)
    notes['duration'].append(end - start)
    prev_start = start

  return pd.DataFrame({name: np.array(value) for name, value in notes.items()}), instrument_name

# %%
def notes_to_midi(
  notes: pd.DataFrame,
  out_file: str,
  instrument_name: str,
  velocity: int = 100,  # note loudness
) -> pretty_midi.PrettyMIDI:
  pm = pretty_midi.PrettyMIDI()
  instrument = pretty_midi.Instrument(
      program=pretty_midi.instrument_name_to_program(
          instrument_name))
  prev_start = 0
  for i, note in notes.iterrows():
    start = float(prev_start + note['step'])
    end = float(start + note['duration'])
    note = pretty_midi.Note(
        velocity=velocity,
        pitch=int(note['pitch']),
        start=start,
        end=end,
    )
    instrument.notes.append(note)
    prev_start = start
  pm.instruments.append(instrument)
  pm.write(out_file)
  return pm

# %%
def predict_next_note(notes, model, temperature) -> int:
  """Generates a note IDs using a trained sequence model."""
  assert temperature > 0
  # Add batch dimension
  inputs = tf.expand_dims(notes, 0)
  predictions = model.predict(inputs)
  pitch_logits = predictions['pitch']
  step = predictions['step']
  duration = predictions['duration']
  pitch_logits /= temperature
  pitch = tf.random.categorical(pitch_logits, num_samples=1)
  pitch = tf.squeeze(pitch, axis=-1)
  duration = tf.squeeze(duration, axis=-1)
  step = tf.squeeze(step, axis=-1)
  # `step` and `duration` values should be non-negative
  step = tf.maximum(0, step)
  duration = tf.maximum(0, duration)
  return int(pitch), float(step), float(duration)

# %%
def mse_with_positive_pressure(y_true: tf.Tensor, y_pred: tf.Tensor):
  mse = (y_true - y_pred) ** 2
  positive_pressure = 10 * tf.maximum(-y_pred, 0.0)
  return tf.reduce_mean(mse + positive_pressure)

# %%
def music_generation(raw_notes, model, num_predictions, instrument_name):
  temperature = 2.0
  #num_predictions = 120
  key_order = ['pitch', 'step', 'duration']
  seq_length = 25
  vocab_size = 128
  sample_notes = np.stack([raw_notes[key] for key in key_order], axis=1)
  # The initial sequence of notes; pitch is normalized similar to training
  # sequences
  input_notes = (
    sample_notes[:seq_length] / np.array([vocab_size, 1, 1]))
  generated_notes = []
  prev_start = 0
  for _ in range(num_predictions):
    pitch, step, duration = predict_next_note(input_notes, model, temperature)
    start = prev_start + step
    end = start + duration
    input_note = (pitch, step, duration)
    generated_notes.append((*input_note, start, end))
    input_notes = np.delete(input_notes, 0, axis=0)
    input_notes = np.append(input_notes, np.expand_dims(input_note, 0), axis=0)
    prev_start = start
  generated_notes = pd.DataFrame(generated_notes, columns=(*key_order, 'start', 'end'))
  out_file = 'output.mid'
  out_pm = notes_to_midi(generated_notes, out_file=out_file, instrument_name=instrument_name)
  files.download(out_file)

# %%
def create_model():
  seq_length = 25
  input_shape = (seq_length, 3)
  learning_rate = 0.005
  inputs = tf.keras.Input(input_shape)
  x = tf.keras.layers.LSTM(128)(inputs)
  outputs = {
  'pitch': tf.keras.layers.Dense(128, name='pitch')(x),
  'step': tf.keras.layers.Dense(1, name='step')(x),
  'duration': tf.keras.layers.Dense(1, name='duration')(x),
  }
  model = tf.keras.Model(inputs, outputs)
  loss = {
      'pitch': tf.keras.losses.SparseCategoricalCrossentropy(
          from_logits=True),
      'step': mse_with_positive_pressure,
      'duration': mse_with_positive_pressure,
  }
  optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
  model.compile(
    loss=loss,
    loss_weights={
        'pitch': 0.05,
        'step': 1.0,
        'duration':1.0,
    },
    optimizer=optimizer,
  )
  return model

# %% [markdown]
# ####Generate music

# %%
emotion = predict(disgust_demo_path)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Parsing file <path: /content/disgust.mov>
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# 17 frames extracted
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# audio_prediction [0. 0. 0. 0. 0. 0. 1. 0.]
# visual_prediction [2.8628809e-02 3.1158663e-05 9.5141745e-01 2.3664670e-05 8.8185063e-03
#  1.1530812e-12 1.5989719e-10 1.1080439e-02]

# %%
def generate_music(path):
  # Globals

  emotion = predict(path)
  ROOT_PATH = '/content/gdrive/My Drive/MLS/MLS Group Project/database/'

  os.chdir(ROOT_PATH)
  emotion_types = {"happy": "Q1", "surprise": "Q1", "angry": "Q2", "fearful": "Q2", "disgust": "Q2", "sad": "Q3", "calm": "Q4", "neutral": "Q4"}
  folder_name = "MER_audio/" + emotion_types[emotion]

  # mapping
  emotion_types = {"happy": "Q1", "surprise": "Q1", "angry": "Q2", "fearful": "Q2", "disgust": "Q2", "sad": "Q3", "calm": "Q4", "neutral": "Q4"}
  folder_name = "MER_audio/" + emotion_types[emotion]

  files1=[os.path.join(ROOT_PATH, folder_name) + "/" + i for i in os.listdir(os.path.join(ROOT_PATH, folder_name)) if i.endswith(".midi")]

  random_number = random.randint(0, len(files1)-1)
  sample_file = files1[random_number]

  raw_notes, instrument_name = midi_to_notes(sample_file)
  raw_notes.head()

  model_checkpoint_path = "./training_checkpoints/" + emotion_types[emotion] + "/"
  print(f"model_checkpoint_path: {model_checkpoint_path}")

  ckpt_path = tf.train.latest_checkpoint(model_checkpoint_path)
  print(f"ckpt_path: {ckpt_path}")

  model = create_model()
  model.load_weights(ckpt_path)

  num_predictions = 240

  music_generation(raw_notes, model, num_predictions, instrument_name)

# %%
generate_music(disgust_demo_path)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# Parsing file <path: /content/disgust.mov>
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Captured!
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
# Trying to capture...
